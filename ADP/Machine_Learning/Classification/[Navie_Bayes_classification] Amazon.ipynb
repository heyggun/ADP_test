# %% [markdown]
# ## 나이브 베이즈 분류(Navie Bayes Classfication)

# %% [markdown]
#     - 나이브 베이즈 분류는 scikit-learn의 naive_bayes 라이브러리 사용
#     - 나이브 베이즈 분류 (1) GaussianNB, (2) BernoulliNB, (3) MultinomialNB

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### `Data1` : Amazon product data (아마존 상품 리뷰의 긍정과 부정 분석)
#
# 데이터 : https://www.kaggle.com/datasets/sameersmahajan/reviews-of-amazon-baby-products

# %% [markdown]
#     - 나이브 베이즈 모델을 활요애하기 위해서는 먼저 데이터를 scikit-learn이 활용할 수 있는 형태로
#     transform 필요
#     - CounterVectorizer 객체를 생성해서 fit() 메서드로 단어를 학습시켜야 함

# %%
os.listdir('./data/')
# Out:
# ['amazon_baby.csv']

# %%
data = pd.read_csv('./data/amazon_baby.csv')
data
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [183531 rows x 3 columns]

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
data['rating'].value_counts(dropna=False)
# Out:
# 5    107054
# 4     33205
# 3     16779
# 1     15183
# 2     11310
# Name: rating, dtype: int64

# %%
data.isnull().sum()
# Out:
# name      318
# review    829
# rating      0
# dtype: int64

# %%
data = data.dropna()
data.isnull().sum()
# Out:
# name      0
# review    0
# rating    0
# dtype: int64

# %% [markdown]
#     - 리뷰의 rating이 4점 이상이면 긍정, 그 미만이면 부정으로 분류함

# %%
a_data = data.copy()

# %%
a_data['rating'] = a_data['rating'].apply(lambda x: 'pos' if int(x) >=4 else 'neg')
a_data['rating'].value_counts(dropna=False)
# Out:
# pos    139318
# neg     43066
# Name: rating, dtype: int64

# %%
a_data
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review rating
# 0       These flannel wipes are OK, but in my opinion ...    neg
# 1       it came early and was not disappointed. i love...    pos
# 2       Very soft and comfortable and warmer than it l...    pos
# 3       This is a product well worth the purchase.  I ...    pos
# 4       All of my kids have cried non-stop when I trie...    pos
# ...                                                   ...    ...
# 183526  Such a great idea! very handy to have and look...    pos
# 183527  This product rocks!  It is a great blend of fu...    pos
# 183528  This item looks great and cool for my kids.......    pos
# 183529  I am extremely happy with this product. I have...    pos
# 183530  I love this product very mush . I have bought ...    pos
#
# [182384 rows x 3 columns]

# %% [markdown]
#     - 데이터가 많고 불균형 하기 때문에 random sampling 으로 각 1000개만 가져와서 사용해봄

# %%
a_data = a_data[['review','rating']]
a_p_data = a_data.loc[a_data['rating']=='pos'].sample(1000)
a_n_data = a_data.loc[a_data['rating']=='neg'].sample(1000)

# %%
a_df = pd.concat([a_p_data, a_n_data]).reset_index(drop=True)
a_df['rating'].value_counts(dropna=False)
display(a_df.head(3))
# Out:
#                                               review rating
# 0  I bought this seat based on all the great revi...    pos
# 1  This monitor is great.  It doesn't have video,...    pos
# 2  its very soft. we love it and sure that baby w...    pos

# %% [markdown]
# **Step 1 `CounterVectorizer`**

# %%
a_data = a_df['review'].values.astype('U')
a_data
# Out:
# array(["I bought this seat based on all the great reviews and I was not disappointed. My son just turned 2 and is small for his age and he fits perfectly on this seat. What I also love about the seat is that it doesn't move once you get it on the toilet. I don't have to worry about my son slipping and sliding around as he moves on the potty. I bought 2!",
#        "This monitor is great.  It doesn't have video, but it has all the rest.  I love the tempurature feature, we heat with a pellet stove and it makes it easy for me to monitor at night that the kids rooms are warm enough.  Very sensitive, but has a control for that as well.  The only down fall of this monitor is that the lights do light up my room quite a bit, since we use a noise machine in the kids rooms.  Great product.",
#        'its very soft. we love it and sure that baby will love it too. will use it in car seat and rocker..',
#        ...,
#        'When I received this product the box had a little chemical smell, but I aired it out. The product overall turned out to be a great way to keep my babies hospital band, pics, and clothing.',
#        'Very hard to hold',
#        'Breast pumps are non returnable. If you want to waste your money go ahead and buy this pump. I purchased this pump, hoping to use it for those middle of the night feedings, when I am too exhausted to breastfeed or when my nipples are too sore. Well the pump probably got more milk on my shirt and down my front than actually in the bottle. I think my largest collection was about a half of an once, and that was after about 30 minutes of pumping!'],
#       dtype='<U7442')

# %% [markdown]
#     - 리스트로 받아서 fitting 할 때 에러 난다면 Unicode 변환을 해서 vectorizer fitting 수행

# %%
vectorizer = CountVectorizer()
vectorizer.fit(a_data)
# Out:
# CountVectorizer()

# %% [markdown]
# **Step 2 `transform`**
#
#     - 문자열 목록을 가져와, 학습시켜놓은 사전을 기반으로 어휘의 빈도를 셈
#     - 학습시킨 vectorizer를 .transform() 메서드로 문자열의 배열을 받아 학습된 단어의 빈도수로 변환
#     - counts에는 각 단어가 등장한 빈도수가 저장됨
#
#            * counts의 index : 학습 단어들
#            * counts의 value : 해당 단어의 빈도 수

# %%
vectorizer.vocabulary_
# Out:
# {'bought': 1024,
#  'this': 7492,
#  'seat': 6354,
#  'based': 787,
#  'on': 4967,
#  'all': 454,
#  'the': 7443,
#  'great': 3317,
#  'reviews': 6091,
#  'and': 512,
#  'was': 8081,
#  'not': 4876,
#  'disappointed': 2221,
#  'my': 4748,
#  'son': 6803,
#  'just': 3981,
#  'turned': 7752,
#  'is': 3899,
#  'small': 6700,
#  'for': 3016,
#  'his': 3543,
#  'age': 415,
#  'he': 3459,
#  'fits': 2921,
#  'perfectly': 5252,
#  'what': 8160,
#  'also': 473,
#  'love': 4339,
#  'about': 275,
#  'that': 7439,
#  'it': 3907,
#  'doesn': 2309,
#  'move': 4702,
#  'once': 4968,
#  'you': 8354,
#  'get': 3201,
#  'toilet': 7580,
#  'don': 2320,
#  'have': 3451,
#  'to': 7569,
#  'worry': 8291,
#  'slipping': 6683,
#  'sliding': 6669,
#  'around': 610,
#  'as': 623,
#  'moves': 4709,
#  'potty': 5489,
#  'monitor': 4664,
#  'video': 7995,
#  'but': 1191,
#  'has': 3437,
#  'rest': 6041,
#  'tempurature': 7405,
#  'feature': 2832,
#  'we': 8115,
#  'heat': 3478,
#  'with': 8245,
#  'pellet': 5242,
#  'stove': 7097,
#  'makes': 4399,
#  'easy': 2471,
#  'me': 4492,
#  'at': 648,
#  'night': 4842,
#  'kids': 4011,
#  'rooms': 6159,
#  'are': 596,
#  'warm': 8065,
#  'enough': 2588,
#  'very': 7982,
#  'sensitive': 6404,
#  'control': 1766,
#  'well': 8148,
#  'only': 4973,
#  'down': 2344,
#  'fall': 2783,
#  'of': 4943,
#  'lights': 4220,
#  'do': 2302,
#  'light': 4212,
#  'up': 7888,
#  'room': 6156,
#  'quite': 5741,
#  'bit': 924,
#  'since': 6597,
#  'use': 7915,
#  'noise': 4856,
#  'machine': 4377,
#  'in': 3709,
#  'product': 5597,
#  'its': 3914,
#  'soft': 6767,
#  'sure': 7262,
#  'baby': 712,
#  'will': 8213,
#  'too': 7594,
#  'car': 1257,
#  'rocker': 6142,
#  'camera': 1227,
#  'unbelievable': 7796,
#  'picture': 5305,
#  'phenomenal': 5281,
#  'zoom': 8387,
#  'awesome': 695,
#  'be': 819,
#  'able': 273,
#  'pan': 5145,
#  'wish': 8239,
#  'come': 1598,
#  'true': 7724,
#  'infant': 3760,
#  'quickly': 5730,
#  'realized': 5825,
#  'even': 2647,
#  'better': 892,
#  'active': 342,
#  'toddler': 7572,
#  'who': 8190,
#  'habit': 3378,
#  'getting': 3203,
#  'out': 5045,
#  'bed': 841,
#  'into': 3863,
#  'mischief': 4606,
#  'places': 5352,
#  'like': 4223,
#  'her': 3506,
#  'clothes': 1533,
#  'closet': 1528,
#  'comes': 1599,
#  'handy': 3411,
#  'when': 8167,
#  'want': 8058,
#  'know': 4050,
#  'if': 3661,
#  'she': 6475,
#  'really': 5827,
#  'sleeping': 6655,
#  'or': 5005,
#  'faking': 2782,
#  'can': 1232,
#  'see': 6375,
#  'whether': 8173,
#  'eyes': 2753,
#  'way': 8111,
#  'closed': 1523,
#  'other': 5033,
#  'summer': 7226,
#  'handheld': 3401,
#  'which': 8176,
#  'been': 851,
#  'using': 7925,
#  'years': 8344,
#  'no': 4852,
#  'issue': 3905,
#  'now': 4891,
#  'pricey': 5564,
#  'absolutely': 279,
#  'worth': 8295,
#  'issues': 3906,
#  'vision': 8009,
#  'try': 7731,
#  'adding': 355,
#  'some': 6792,
#  'led': 4163,
#  'nightlights': 4844,
#  'perimeter': 5262,
#  'daughter': 2007,
#  'bites': 926,
#  'crib': 1894,
#  'rail': 5756,
#  'from': 3093,
#  'time': 7544,
#  'one': 4969,
#  'day': 2014,
#  'found': 3046,
#  'there': 7457,
#  'scraps': 6319,
#  'ordered': 5013,
#  'immediately': 3678,
#  'then': 7453,
#  'problem': 5585,
#  'solved': 6789,
#  'little': 4269,
#  'expensive': 2713,
#  'give': 3221,
#  'star': 6988,
#  'year': 8343,
#  'old': 4960,
#  'grandson': 3301,
#  'got': 3267,
#  'christmas': 1442,
#  'loves': 4343,
#  'mommy': 4660,
#  'reads': 5818,
#  'him': 3534,
#  'good': 3258,
#  'quality': 5715,
#  'made': 4379,
#  'positive': 5468,
#  'directed': 2207,
#  'buy': 1197,
#  'never': 4820,
#  'expected': 2708,
#  'nice': 4834,
#  'came': 1226,
#  'few': 2860,
#  'days': 2016,
#  'granddaughter': 3293,
#  'cadillac': 1210,
#  'strollers': 7147,
#  'price': 5558,
#  'clock': 1517,
#  'hands': 3407,
#  'hoping': 3582,
#  'make': 4397,
#  'cute': 1965,
#  'nursery': 4905,
#  'didn': 2175,
#  'boring': 1006,
#  'numbers': 4899,
#  'so': 6753,
#  'searched': 6351,
#  'wall': 8049,
#  'stickers': 7046,
#  'finally': 2892,
#  'these': 7466,
#  'perfect': 5251,
#  'because': 836,
#  'different': 2183,
#  'size': 6622,
#  'circles': 1456,
#  'ranges': 5777,
#  'inches': 3714,
#  'diameter': 2167,
#  'put': 5706,
#  'big': 904,
#  'main': 4390,
#  'quarter': 5719,
#  '12': 22,
#  'smaller': 6701,
#  'between': 893,
#  've': 7954,
#  'gotten': 3269,
#  'lot': 4329,
#  'compliments': 1660,
#  'people': 5246,
#  'our': 5042,
#  'second': 6361,
#  'order': 5012,
#  'they': 7469,
#  'sippy': 6608,
#  'cups': 1939,
#  'ever': 2656,
#  'leak': 4141,
#  'takes': 7346,
#  'filled': 2881,
#  'water': 8104,
#  'every': 2657,
#  'finding': 2895,
#  'puddle': 5659,
#  'done': 2322,
#  'hold': 3550,
#  'beautifully': 833,
#  'did': 2173,
#  'extra': 2746,
#  'valves': 7941,
#  'leaked': 4143,
#  'grungy': 3351,
#  'were': 8151,
#  'hard': 3425,
#  'clean': 1482,
#  'given': 3223,
#  'how': 3610,
#  'buying': 1201,
#  'still': 7053,
#  'best': 890,
#  'bath': 801,
#  'live': 4271,
#  'apartment': 554,
#  'needed': 4793,
#  'tub': 7735,
#  'compact': 1625,
#  'store': 7090,
#  'first': 2914,
#  'had': 3381,
#  'puj': 5664,
#  'seemed': 6380,
#  'solution': 6786,
#  'actually': 347,
#  'sinks': 6605,
#  'unsnapped': 7871,
#  'soon': 6810,
#  'placed': 5349,
#  'wasn': 8094,
#  'fully': 3111,
#  'supported': 7253,
#  'over': 5073,
#  'friend': 3085,
#  'house': 3603,
#  'saw': 6274,
#  'bathing': 803,
#  'month': 4673,
#  'amazed': 486,
#  'comfortable': 1601,
#  'hefty': 3490,
#  'boy': 1046,
#  'line': 4238,
#  'more': 4680,
#  'by': 1204,
#  'inexpensive': 3758,
#  'tag': 7338,
#  'compared': 1632,
#  'tubs': 7738,
#  'market': 4444,
#  'haven': 3452,
#  'looked': 4305,
#  'back': 727,
#  'single': 6603,
#  'basin': 793,
#  'kitchen': 4030,
#  'sink': 6604,
#  'although': 478,
#  'position': 5459,
#  'along': 467,
#  'diagonal': 2164,
#  'loved': 4340,
#  'beginning': 859,
#  'sits': 6614,
#  'without': 8250,
#  'any': 541,
#  'complaint': 1650,
#  'though': 7496,
#  'long': 4300,
#  'having': 3456,
#  'legs': 4174,
#  'scrunched': 6338,
#  'inside': 3802,
#  'an': 505,
#  'suction': 7200,
#  'bottom': 1020,
#  'shift': 6494,
#  'while': 8180,
#  'kicks': 4004,
#  'away': 693,
#  'stores': 7092,
#  'neatly': 4784,
#  'linen': 4240,
#  'would': 8299,
#  'probably': 5583,
#  'fit': 2918,
#  'most': 4685,
#  'under': 7807,
#  'cabinets': 1207,
#  'pedestal': 5227,
#  'keep': 3988,
#  'recommend': 5873,
#  'anyone': 545,
#  'already': 471,
#  'purchased': 5685,
#  'brother': 1111,
#  'new': 4822,
#  'bedding': 842,
#  'after': 411,
#  'holding': 3553,
#  'fine': 2897,
#  'quilted': 5736,
#  'comforter': 1605,
#  'thin': 7479,
#  'works': 8284,
#  'blankets': 937,
#  'looks': 4309,
#  'isn': 3903,
#  'outrageously': 5065,
#  'priced': 5559,
#  'their': 7446,
#  'job': 3942,
#  'difficult': 2185,
#  'pull': 5665,
#  'socket': 6762,
#  'need': 4792,
#  'point': 5413,
#  'airplane': 434,
#  'trip': 7710,
#  'wanted': 8059,
#  'close': 1522,
#  'top': 7603,
#  'completely': 1653,
#  'traveling': 7682,
#  'normal': 4870,
#  'lid': 4199,
#  'cup': 1935,
#  'purport': 5692,
#  'held': 3495,
#  'downward': 2353,
#  'angle': 516,
#  'upside': 7905,
#  'excellent': 2672,
#  'cover': 1844,
#  'polka': 5429,
#  'dot': 2335,
#  'covered': 1846,
#  'boppy': 1002,
#  'originally': 5027,
#  'fabric': 2757,
#  'sandpaper': 6250,
#  'wouldn': 8300,
#  'sleep': 6652,
#  'organic': 5018,
#  'jersey': 3935,
#  'knit': 4041,
#  'super': 7241,
#  'neutral': 4819,
#  'newborn': 4824,
#  'does': 2308,
#  'tummy': 7744,
#  'face': 2761,
#  'rubs': 6191,
#  'against': 414,
#  'problems': 5587,
#  'two': 7770,
#  'highly': 3527,
#  'recommended': 5875,
#  'covers': 1848,
#  'amazing': 487,
#  'swing': 7308,
#  'relatively': 5937,
#  'together': 7576,
#  'cradle': 1860,
#  'switch': 7312,
#  'modes': 4643,
#  'recline': 5863,
#  'upright': 7901,
#  'change': 1341,
#  'show': 6535,
#  'pretty': 5548,
#  'enjoy': 2582,
#  'real': 5820,
#  'uses': 7924,
#  'power': 5501,
#  'cord': 1799,
#  'instead': 3820,
#  'battery': 812,
#  'full': 3109,
#  'charge': 1355,
#  'turn': 7750,
#  'mode': 4636,
#  'batteries': 810,
#  'outlet': 5061,
#  'regular': 5926,
#  'standard': 6982,
#  'service': 6428,
#  'wasnt': 8095,
#  'going': 3254,
#  'matresses': 4477,
#  'resistant': 6025,
#  'anyway': 548,
#  'glad': 3227,
#  'much': 4717,
#  'nicer': 4837,
#  'substitute': 7187,
#  'your': 8358,
#  'child': 1403,
#  'sound': 6831,
#  'plastic': 5366,
#  'bags': 751,
#  'mine': 4586,
#  'entire': 2600,
#  'skirt': 6641,
#  'same': 6244,
#  'crinkle': 1900,
#  'staring': 6992,
#  'doll': 2314,
#  'cost': 1816,
#  'apparently': 559,
#  'say': 6275,
#  'll': 4276,
#  'gets': 3202,
#  'older': 4961,
#  'likes': 4227,
#  'paid': 5128,
#  'girl': 3214,
#  'tummytub': 7745,
#  'home': 3561,
#  'hospital': 3596,
#  'high': 3521,
#  'chair': 1331,
#  'versatile': 7976,
#  'convenient': 1771,
#  'sturdy': 7172,
#  'grow': 3346,
#  'everyday': 2659,
#  'restuarants': 6057,
#  'grandpa': 3299,
#  'family': 2792,
#  'togethers': 7577,
#  'husband': 3640,
#  'sceptic': 6303,
#  'showed': 6536,
#  'look': 4304,
#  'safe': 6223,
#  'impressed': 3696,
#  'secure': 6368,
#  'straps': 7116,
#  'connecting': 1703,
#  'tray': 7686,
#  'off': 4945,
#  'find': 2894,
#  'place': 5348,
#  'thing': 7480,
#  'money': 4663,
#  'spent': 6877,
#  'designed': 2124,
#  'foldable': 2995,
#  'diaper': 2168,
#  'bag': 744,
#  'purchase': 5684,
#  'again': 413,
#  'sacks': 6217,
#  'aden': 362,
#  'anais': 506,
#  'them': 7449,
#  'believe': 870,
#  'feel': 2845,
#  'realistic': 5822,
#  '25': 116,
#  '30': 147,
#  'bullet': 1153,
#  'each': 2456,
#  'mainly': 4391,
#  'climber': 1507,
#  'climbing': 1508,
#  'material': 4475,
#  'sleeve': 6660,
#  'pant': 5151,
#  'pj': 5345,
#  'liked': 4224,
#  'stayed': 7016,
#  'opposed': 4994,
#  'experienced': 2715,
#  'zippers': 8381,
#  'said': 6234,
#  'differently': 2184,
#  'keeping': 3990,
#  'arrive': 614,
#  'august': 672,
#  'decals': 2033,
#  'draw': 2371,
#  'textured': 7431,
#  'walls': 8052,
#  'stick': 7043,
#  'decal': 2032,
#  'collection': 1578,
#  'five': 2924,
#  'difficulty': 2187,
#  'sticking': 7047,
#  'bad': 741,
#  'think': 7482,
#  'may': 4488,
#  'due': 2437,
#  'fact': 2766,
#  'packaging': 5117,
#  'crease': 1882,
#  'slightly': 6672,
#  'folded': 2996,
#  'quinny': 5738,
#  'zapp': 8370,
#  'xtra': 8334,
#  'especially': 2629,
#  'colour': 1589,
#  'why': 8197,
#  'image': 3672,
#  'showing': 6540,
#  'four': 3047,
#  'wheels': 8166,
#  'tripod': 7713,
#  'wheel': 8164,
#  'structure': 7154,
#  'than': 7433,
#  'thought': 7497,
#  'three': 7505,
#  'setting': 6436,
#  'music': 4741,
#  'tunes': 7748,
#  'ocean': 4934,
#  'sounds': 6835,
#  'white': 8188,
#  'awake': 691,
#  'lull': 4358,
#  'wakes': 8041,
#  'eat': 2472,
#  'middle': 4572,
#  'downside': 2349,
#  'quiet': 5731,
#  'loud': 4334,
#  'next': 4830,
#  'nooks': 4867,
#  'corners': 1803,
#  'unit': 7837,
#  'lasted': 4099,
#  'through': 7510,
#  'cleanups': 1494,
#  'am': 485,
#  'satisfied': 6260,
#  'oxo': 5102,
#  'brand': 1057,
#  'items': 3913,
#  'cleanliness': 1487,
#  'godliness': 3251,
#  'should': 6528,
#  'right': 6116,
#  'hymnal': 3645,
#  'gift': 3206,
#  'law': 4123,
#  'went': 8150,
#  'stroller': 7146,
#  'easily': 2467,
#  '6wks': 235,
#  'early': 2460,
#  'info': 3771,
#  'months': 4675,
#  'strap': 7111,
#  'stars': 6994,
#  'item': 3912,
#  'cotton': 1826,
#  'bumper': 1163,
#  'mini': 4587,
#  'cribs': 1895,
#  'amazingly': 488,
#  'looking': 4308,
#  'recreate': 5880,
#  'pottery': 5487,
#  'barn': 782,
#  'restoration': 6051,
#  'hardware': 3429,
#  'grey': 3325,
#  'ticket': 7521,
#  'fraction': 3051,
#  'needs': 4796,
#  'glide': 3233,
#  'wood': 8270,
#  'floors': 2969,
#  'trouble': 7719,
#  'carpet': 1269,
#  'tile': 7538,
#  'assemble': 634,
#  'feminine': 2853,
#  'toys': 7642,
#  'occupied': 4929,
#  'buzzing': 1203,
#  '34': 166,
#  '99': 264,
#  'ross': 6165,
#  'arrived': 615,
#  'isnt': 3904,
#  'return': 6074,
#  'something': 6797,
#  'assembled': 635,
#  'smell': 6706,
#  'babies': 710,
#  'vulli': 8029,
#  'products': 5601,
#  'superior': 7244,
#  'large': 4093,
#  'stash': 7002,
#  'many': 4436,
#  'brands': 1059,
#  'diapers': 2171,
#  'elastic': 2508,
#  'worn': 8288,
#  'almost': 465,
#  'third': 7487,
#  'half': 3386,
#  'crafty': 1862,
#  'affordable': 408,
#  'round': 6174,
#  'prints': 5577,
#  'partial': 5173,
#  'print': 5575,
#  'gray': 3314,
#  'tabs': 7332,
#  'hopefully': 3580,
#  'future': 3136,
#  'option': 5001,
#  'pick': 5298,
#  'color': 1580,
#  'gussets': 3371,
#  'liner': 4241,
#  'helps': 3503,
#  'pee': 5230,
#  'poop': 5434,
#  'charcoal': 1353,
#  'hide': 3516,
#  'stains': 6974,
#  'bamboo': 762,
#  'skin': 6634,
#  'soaking': 6757,
#  'wet': 8155,
#  'being': 867,
#  'soiled': 6774,
#  'kawaii': 3986,
#  'mom': 4654,
#  'label': 4060,
#  'inserts': 3801,
#  'go': 3247,
#  'front': 3094,
#  'charlie': 1362,
#  'banana': 763,
#  'less': 4183,
#  'likely': 4226,
#  'stuck': 7159,
#  'insert': 3797,
#  'flap': 2934,
#  'thick': 7472,
#  'absorb': 281,
#  'positioning': 5463,
#  'snaps': 6734,
#  'cause': 1301,
#  'leaks': 4146,
#  'prefer': 5519,
#  'thee': 7444,
#  'positioned': 5461,
#  'towards': 7633,
#  'faster': 2814,
#  'easier': 2465,
#  'owners': 5099,
#  'company': 1629,
#  'wonderful': 8265,
#  'thanked': 7435,
#  'pleasant': 5393,
#  'surprise': 7268,
#  'above': 276,
#  'beyond': 897,
#  'happy': 3424,
#  'admirable': 377,
#  'definitely': 2071,
#  'appreciated': 576,
#  'fold': 2994,
#  'booster': 996,
#  'noticed': 4885,
#  'complained': 1647,
#  'cracks': 1858,
#  'food': 3006,
#  'take': 7344,
#  'apart': 553,
#  'dishwasher': 2254,
#  'directions': 2209,
#  'springs': 6936,
#  'rust': 6212,
#  'occasionally': 4927,
#  'floor': 2968,
#  'wants': 8061,
#  'rub': 6184,
#  'crayongs': 1875,
#  'paper': 5155,
#  'life': 4204,
#  'saver': 6270,
#  'couldn': 1829,
#  'calm': 1220,
#  'worked': 8279,
#  'gifts': 3208,
#  'strong': 7148,
#  'multiple': 4726,
#  'lightweight': 4221,
#  'marquisette': 4451,
#  'blanket': 936,
#  'ideal': 3654,
#  'nursing': 4908,
#  'plenty': 5397,
#  'lay': 4125,
#  'play': 5373,
#  'course': 1842,
#  'swaddling': 7289,
#  'skill': 6632,
#  'learned': 4153,
#  'another': 532,
#  'printed': 5576,
#  'attached': 654,
#  'always': 484,
#  'showers': 6539,
#  'invited': 3879,
#  'winter': 8228,
#  'duo': 2444,
#  'late': 4107,
#  'spring': 6935,
#  'beautiful': 832,
#  'timeless': 7547,
#  'sadly': 6221,
#  'read': 5812,
#  '2013': 81,
#  'wait': 8036,
#  'such': 7193,
#  'until': 7878,
#  'pillow': 5319,
#  'wraps': 8311,
#  'body': 979,
#  'sides': 6558,
#  'pumping': 5675,
#  'exclusively': 2687,
#  'week': 8132,
#  'difficulties': 2186,
#  'breastfeeding': 1076,
#  'free': 3063,
#  'pump': 5672,
#  'weeks': 8137,
#  'ameda': 491,
#  'double': 2337,
#  'electric': 2513,
#  'breast': 1071,
#  'relief': 5948,
#  'wearing': 8122,
#  '36c': 181,
#  'master': 4467,
#  'bedroom': 843,
#  'opposite': 4995,
#  'end': 2561,
#  'clearly': 1499,
#  'lcd': 4133,
#  'peacefully': 5222,
#  'watch': 8101,
#  'simply': 6593,
#  'stirring': 7063,
#  'wide': 8201,
#  'screen': 6329,
#  'view': 7998,
#  'distance': 2281,
#  'where': 8169,
#  'reception': 5854,
#  'approximately': 587,
#  'feet': 2849,
#  'clipping': 1515,
#  'belt': 878,
#  'walking': 8047,
#  'cleaning': 1486,
#  'during': 2449,
#  'naptime': 4764,
#  'nicely': 4835,
#  'counter': 1833,
#  'flat': 2940,
#  'surface': 7264,
#  'toy': 7640,
#  'recently': 5853,
#  'discovered': 2242,
#  'rubber': 6186,
#  'duckies': 2431,
#  'float': 2964,
#  'overall': 5074,
#  'provided': 5650,
#  'hours': 3602,
#  'fun': 3113,
#  'seems': 6382,
#  'detachable': 2140,
#  'friends': 3087,
#  'took': 7595,
#  'liking': 4229,
#  'monkey': 4668,
#  'everywhere': 2663,
#  'washable': 8083,
#  'twins': 7764,
#  'daily': 1979,
#  '128077': 26,
#  '128125': 27,
#  'grip': 3329,
#  'threw': 7506,
#  'across': 335,
#  '3rd': 193,
#  '16': 46,
#  'alot': 469,
#  'walk': 8044,
#  'oldest': 4962,
#  'preschool': 5538,
#  'dont': 2324,
#  'giant': 3205,
#  'help': 3498,
#  'falls': 2787,
#  'asleep': 630,
#  'involve': 3880,
#  'bring': 1099,
#  'those': 7495,
#  'digging': 2190,
#  'shoulders': 6531,
#  'yet': 8349,
#  'wear': 8120,
#  'straight': 7101,
#  'both': 1010,
#  'cross': 1908,
#  'thats': 7441,
#  'usually': 7927,
#  'doesnt': 2310,
#  'slip': 6679,
#  'adjust': 368,
#  'tighten': 7529,
#  'loosen': 4314,
#  'primarily': 5568,
#  'feeding': 2842,
#  'started': 6996,
#  'bottle': 1015,
#  'milk': 4579,
#  'ease': 2464,
#  'convinience': 1782,
#  'avent': 683,
#  'bottles': 1017,
#  'frequently': 3073,
#  'spit': 6898,
#  'latching': 4106,
#  'onto': 4975,
#  'tried': 7701,
#  'dr': 2358,
#  'brown': 1113,
#  'neck': 4789,
#  'spiting': 6899,
#  'overspill': 5091,
#  'etc': 2641,
#  'importantly': 3693,
#  'steps': 7035,
#  'exactly': 2668,
#  'target': 7367,
#  'extremely': 2748,
#  'checked': 1376,
#  'amazon': 489,
#  'clear': 1495,
#  'seller': 6393,
#  'delivered': 2088,
#  'working': 8282,
#  'twin': 7762,
#  'frame': 3054,
#  'raised': 5767,
#  'box': 1042,
#  'tell': 7395,
#  'work': 8277,
#  'chance': 1337,
#  'pain': 5131,
#  'keeps': 3991,
#  'shoved': 6534,
#  'mesh': 4542,
#  'alternative': 476,
#  'bright': 1091,
#  'colors': 1585,
#  'dog': 2311,
#  'design': 2121,
#  'stimulate': 7054,
#  'however': 3611,
#  'plush': 5406,
#  'case': 1289,
#  'greatly': 3321,
#  'enjoyed': 2583,
#  'previous': 5556,
#  'thoroughly': 7494,
#  'enjoying': 2584,
#  'commented': 1614,
#  'colourful': 1591,
#  'continue': 1754,
#  'discover': 2241,
#  'aspects': 632,
#  'pleased': 5396,
#  'stylish': 7175,
#  'practical': 5504,
#  'simple': 6589,
#  'options': 5003,
#  'serves': 6427,
#  'purpose': 5694,
#  'fairly': 2779,
#  'id': 3652,
#  'youre': 8359,
#  'costly': 1819,
#  'bigger': 905,
#  'chairs': 1332,
#  'lovey': 4344,
#  'received': 5848,
#  'grandmother': 3298,
#  'sugar': 7211,
#  'spice': 6880,
#  'mary': 4457,
#  'jane': 3927,
#  'ish': 3900,
#  'adorable': 381,
#  'pigtails': 5315,
#  'chewing': 1397,
#  'fuzzy': 3141,
#  'silk': 6578,
#  'underside': 7812,
#  'textures': 7432,
#  'decent': 2037,
#  'sized': 6623,
#  'rubbing': 6190,
#  'agree': 420,
#  'review': 6087,
#  'hair': 3385,
#  'wash': 8082,
#  'rotate': 6167,
#  'evenly': 2651,
#  'shower': 6537,
#  'us': 7910,
#  'wherever': 8172,
#  'plug': 5400,
#  'someone': 6795,
#  'rather': 5789,
#  'making': 4400,
#  'pots': 5486,
#  'pans': 5150,
#  ...}

# %%
counts = vectorizer.transform(a_data)
print(counts.shape)
# Out:
# (2000, 8389)

# %% [markdown]
# **Step 3 `naive bayes classification Training`**
#
#     - 데이터 포인트 배열인 counts 객체와 각 데이터 라벨을 전ㄷ라하여 나이브 베이즈 학습
#     - counts 객체를 만들 때, 리뷰 데이터가 긍정 1000개, 부정 1000개 순으로 들어가서
#     1001번째 인덱스까지는 1, 뒤 끝까지는 0으로 라벨링 해줌

# %%
multi_classification = MultinomialNB()

labels = [1] *1000 + [0] *1000

multi_classification.fit(counts, labels)
# Out:
# MultinomialNB()

# %% [markdown]
# **Step 4 `naive bayes classification Prediction`**
#
#     - .predict() : 임의의 데이터 포인트 배열을 전달하여 클래스 예측
#     - .predict_proba() : 주어진 데이터가 특정 클래스에 속할 확률

# %%
print(multi_classification.predict(counts))
# Out:
# [1 1 1 ... 0 0 0]

# %%
print(multi_classification.predict_proba(counts))
# Out:
# [[1.43746714e-03 9.98562533e-01]
#  [4.70895083e-05 9.99952910e-01]
#  [1.15071165e-02 9.88492883e-01]
#  ...
#  [9.86803539e-01 1.31964610e-02]
#  [6.66627968e-01 3.33372032e-01]
#  [9.94138960e-01 5.86104013e-03]]

# %%
review_case1 = "This is bad product. I'm dissatisfied"
print(multi_classification.predict(vectorizer.transform([review_case1])))
print(multi_classification.predict_proba(vectorizer.transform([review_case1])))
# Out:
# [0]
# [[0.92423565 0.07576435]]

# %%
review_case2 = "I think it's ambiguous. I'm just writing because I'm lazy to refund"
print(multi_classification.predict(vectorizer.transform([review_case2])))
print(multi_classification.predict_proba(vectorizer.transform([review_case2])))
# Out:
# [0]
# [[0.93477025 0.06522975]]

# %%
review_case3 = "I guess not bad. sell a lot"
print(multi_classification.predict(vectorizer.transform([review_case3])))
print(multi_classification.predict_proba(vectorizer.transform([review_case3])))
# Out:
# [0]
# [[0.93397293 0.06602707]]

# %% [markdown]
# #### 데이터의 빈도 수 저장 (데이터 긍정/부정 빈도수 저장 Counter 객체 생성)
#
#
#     + 데이터의 빈도 수 저장
#     - 데이터의 긍정, 부정 빈도수를 저장하는 Counter 객체 생성

# %%
# 긍정 리뷰의 단어 빈도수 저장

pos_lst = a_df.loc[a_df['rating']=='pos']['review'].values.tolist()
print(pos_lst[:2])

pos_words = []

for p_sentence in pos_lst:
    pos_words.extend(str(p_sentence).split(' '))

pos_counter = Counter(pos_words)
pos_counter
# Out:
# ["I bought this seat based on all the great reviews and I was not disappointed. My son just turned 2 and is small for his age and he fits perfectly on this seat. What I also love about the seat is that it doesn't move once you get it on the toilet. I don't have to worry about my son slipping and sliding around as he moves on the potty. I bought 2!", "This monitor is great.  It doesn't have video, but it has all the rest.  I love the tempurature feature, we heat with a pellet stove and it makes it easy for me to monitor at night that the kids rooms are warm enough.  Very sensitive, but has a control for that as well.  The only down fall of this monitor is that the lights do light up my room quite a bit, since we use a noise machine in the kids rooms.  Great product."]
# Counter({'I': 2088,
#          'bought': 156,
#          'this': 813,
#          'seat': 121,
#          'based': 9,
#          'on': 631,
#          'all': 204,
#          'the': 3131,
#          'great': 225,
#          'reviews': 33,
#          'and': 2430,
#          'was': 563,
#          'not': 327,
#          'disappointed.': 5,
#          'My': 217,
#          'son': 143,
#          'just': 235,
#          'turned': 10,
#          '2': 84,
#          'is': 1305,
#          'small': 73,
#          'for': 1125,
#          'his': 142,
#          'age': 8,
#          'he': 211,
#          'fits': 61,
#          'perfectly': 20,
#          'seat.': 22,
#          'What': 7,
#          'also': 142,
#          'love': 202,
#          'about': 163,
#          'that': 661,
#          'it': 1529,
#          "doesn't": 82,
#          'move': 19,
#          'once': 26,
#          'you': 313,
#          'get': 173,
#          'toilet.': 1,
#          "don't": 128,
#          'have': 570,
#          'to': 2016,
#          'worry': 16,
#          'my': 811,
#          'slipping': 5,
#          'sliding': 5,
#          'around': 88,
#          'as': 396,
#          'moves': 5,
#          'potty.': 3,
#          '2!': 1,
#          'This': 251,
#          'monitor': 33,
#          'great.': 42,
#          '': 1530,
#          'It': 391,
#          'video,': 1,
#          'but': 497,
#          'has': 260,
#          'rest.': 3,
#          'tempurature': 1,
#          'feature,': 1,
#          'we': 341,
#          'heat': 4,
#          'with': 655,
#          'a': 1694,
#          'pellet': 1,
#          'stove': 3,
#          'makes': 45,
#          'easy': 224,
#          'me': 104,
#          'at': 257,
#          'night': 43,
#          'kids': 44,
#          'rooms': 4,
#          'are': 431,
#          'warm': 14,
#          'enough.': 3,
#          'Very': 46,
#          'sensitive,': 1,
#          'control': 5,
#          'well.': 63,
#          'The': 396,
#          'only': 157,
#          'down': 58,
#          'fall': 24,
#          'of': 845,
#          'lights': 9,
#          'do': 104,
#          'light': 42,
#          'up': 224,
#          'room': 60,
#          'quite': 39,
#          'bit,': 3,
#          'since': 65,
#          'use': 219,
#          'noise': 6,
#          'machine': 8,
#          'in': 874,
#          'rooms.': 3,
#          'Great': 60,
#          'product.': 43,
#          'its': 58,
#          'very': 336,
#          'soft.': 11,
#          'sure': 38,
#          'baby': 290,
#          'will': 182,
#          'too.': 25,
#          'car': 74,
#          'rocker..': 1,
#          'camera': 15,
#          'unbelievable!': 1,
#          'Picture': 1,
#          'phenomenal,': 1,
#          'zoom': 4,
#          'feature': 17,
#          'awesome,': 3,
#          'be': 274,
#          'able': 58,
#          'pan': 2,
#          '-': 105,
#          'wish': 42,
#          'come': 31,
#          'true.': 1,
#          'infant': 20,
#          'quickly': 17,
#          'realized': 3,
#          'even': 104,
#          'better': 53,
#          'active': 1,
#          'toddler': 27,
#          'who': 73,
#          'habit': 1,
#          'getting': 48,
#          'out': 198,
#          'bed': 45,
#          'into': 76,
#          'mischief': 1,
#          'places': 8,
#          'like': 242,
#          'her': 211,
#          'clothes': 6,
#          'closet.': 4,
#          'comes': 39,
#          'handy': 16,
#          'when': 291,
#          'want': 51,
#          'know': 50,
#          'if': 175,
#          'she': 197,
#          'really': 201,
#          'sleeping': 20,
#          'or': 182,
#          'faking': 1,
#          'can': 277,
#          'see': 48,
#          'whether': 3,
#          'eyes': 3,
#          'way': 56,
#          'closed': 7,
#          'not.': 4,
#          'other': 163,
#          'Summer': 4,
#          'Infant': 8,
#          'handheld': 3,
#          'which': 109,
#          'been': 116,
#          'using': 106,
#          'years': 26,
#          'no': 127,
#          'issue,': 1,
#          'now': 112,
#          'infant.': 4,
#          'pricey': 6,
#          'absolutely': 32,
#          'worth': 43,
#          'it.': 173,
#          'And': 35,
#          'issues': 20,
#          'vision,': 2,
#          'try': 26,
#          'adding': 2,
#          'some': 96,
#          'LED': 1,
#          'nightlights': 1,
#          'perimeter': 1,
#          'room.': 16,
#          'daughter': 129,
#          'bites': 1,
#          'crib': 41,
#          'rail': 8,
#          'from': 158,
#          'time': 95,
#          'time.': 30,
#          'But': 43,
#          'one': 275,
#          'day': 41,
#          'found': 51,
#          'there': 86,
#          'scraps': 1,
#          'out.': 26,
#          'ordered': 43,
#          'immediately': 11,
#          'then': 54,
#          'problem': 37,
#          'solved.': 2,
#          'Since': 13,
#          "it's": 179,
#          'little': 251,
#          'bit': 59,
#          'expensive,': 3,
#          'give': 44,
#          '4': 55,
#          'star.': 2,
#          'year': 78,
#          'old': 158,
#          'grandson': 15,
#          'got': 79,
#          'Christmas': 8,
#          'loves': 166,
#          'Mommy': 2,
#          'reads': 1,
#          'him.': 15,
#          'Good': 13,
#          'quality': 50,
#          'well': 124,
#          'made.': 7,
#          'Other': 14,
#          'positive': 9,
#          'directed': 1,
#          'buy': 63,
#          'never': 59,
#          'expected': 16,
#          'nice': 75,
#          'was,': 2,
#          'came': 30,
#          'few': 55,
#          'days': 20,
#          'granddaughter': 13,
#          'Cadillac': 1,
#          'strollers...': 1,
#          'We': 229,
#          'price...': 1,
#          'clock': 9,
#          'hands': 16,
#          'hoping': 8,
#          'make': 64,
#          'cute': 45,
#          'nursery': 12,
#          "didn't": 59,
#          'boring': 2,
#          'numbers': 1,
#          'so': 481,
#          'searched': 4,
#          'wall': 13,
#          'stickers': 5,
#          'finally': 16,
#          'these.': 11,
#          "It's": 122,
#          'perfect': 77,
#          'because': 146,
#          'different': 49,
#          'size': 52,
#          'circles.': 1,
#          'ranges': 1,
#          '6': 34,
#          'inches': 5,
#          'diameter': 1,
#          'inches.': 2,
#          'put': 148,
#          'big': 66,
#          'circles': 3,
#          'main': 12,
#          'quarter': 1,
#          '(12': 1,
#          '3': 66,
#          '9)': 1,
#          'smaller': 16,
#          'between.': 1,
#          "I've": 54,
#          'gotten': 13,
#          'lot': 52,
#          'compliments': 8,
#          'people': 23,
#          "baby's": 29,
#          ':)': 22,
#          'Our': 44,
#          'second': 27,
#          'order': 23,
#          'these': 172,
#          'they': 233,
#          'ONLY': 3,
#          'sippy': 20,
#          'cups': 17,
#          'EVER': 1,
#          'leak.': 3,
#          'takes': 26,
#          'filled': 2,
#          'water': 26,
#          'every': 47,
#          'finding': 2,
#          'him': 107,
#          'puddle': 1,
#          "we've": 15,
#          'done': 18,
#          'cups.': 7,
#          'These': 53,
#          'hold': 48,
#          'beautifully.': 1,
#          'did': 54,
#          'extra': 34,
#          'valves--not': 1,
#          'leaked': 4,
#          'grungy': 1,
#          'were': 85,
#          'hard': 38,
#          'clean.': 14,
#          'Given': 1,
#          'how': 97,
#          'awesome': 6,
#          'are,': 3,
#          'buying': 25,
#          'valves': 3,
#          'still': 131,
#          'BEST': 1,
#          'bath': 24,
#          'around!': 2,
#          'live': 14,
#          'apartment': 3,
#          'needed': 29,
#          'seat/tub': 1,
#          'compact': 9,
#          'store.': 6,
#          'first': 94,
#          'had': 215,
#          'Puj': 1,
#          'Tub,': 1,
#          'seemed': 13,
#          'solution,': 1,
#          'actually': 44,
#          'too': 99,
#          'SMALL': 1,
#          'our': 205,
#          'sinks.': 1,
#          'unsnapped': 1,
#          'soon': 11,
#          'placed': 6,
#          "wasn't": 16,
#          'fully': 9,
#          'supported': 1,
#          'around.': 7,
#          'Then,': 1,
#          'over': 85,
#          "friend's": 4,
#          'house': 23,
#          'saw': 11,
#          'bathing': 7,
#          'month': 75,
#          'amazed': 5,
#          'well-supported': 1,
#          'comfortable': 50,
#          '(hefty)': 1,
#          'boy': 17,
#          'it!': 56,
#          'then,': 1,
#          'on-line,': 1,
#          'more': 131,
#          'by': 95,
#          'inexpensive': 7,
#          'price': 41,
#          'tag': 3,
#          'compared': 15,
#          'tubs': 2,
#          'market.': 3,
#          "haven't": 36,
#          'looked': 20,
#          'back!': 1,
#          'single': 12,
#          'basin': 1,
#          'kitchen': 5,
#          'sink': 5,
#          '(although': 3,
#          'position': 10,
#          'along': 12,
#          'diagonal': 1,
#          'sink).': 1,
#          'loved': 51,
#          'beginning.': 1,
#          'He': 73,
#          'sits': 9,
#          'without': 61,
#          'any': 101,
#          'complaint.': 2,
#          'tub,': 7,
#          'though,': 11,
#          'long': 46,
#          'having': 53,
#          'legs': 14,
#          'scrunched': 2,
#          'inside': 23,
#          '(this': 1,
#          'an': 118,
#          'issue': 23,
#          'SINK,': 1,
#          'seat).': 1,
#          'suction': 11,
#          'bottom,': 2,
#          'shift': 4,
#          'tub': 12,
#          'while': 71,
#          'kicks': 3,
#          'away': 24,
#          'water!': 1,
#          'Best': 11,
#          'all,': 11,
#          'stores': 5,
#          'neatly': 1,
#          'linen': 3,
#          'closet': 4,
#          'would': 216,
#          'probably': 19,
#          'fit': 87,
#          'most': 42,
#          'under-sink': 1,
#          'cabinets': 8,
#          '(we': 8,
#          'pedestal': 1,
#          'sink,': 2,
#          'keep': 77,
#          'closet).': 2,
#          'recommend': 109,
#          'ANYONE': 1,
#          'already': 24,
#          'purchased': 61,
#          "brother's": 1,
#          'new': 58,
#          'baby!': 4,
#          'bedding,': 1,
#          'after': 92,
#          'holding': 21,
#          'fine.': 12,
#          'quilted': 2,
#          'comforter': 3,
#          'thin,': 3,
#          'fine': 11,
#          'works': 69,
#          'blankets.': 3,
#          'All': 15,
#          'looks': 46,
#          'nice,': 6,
#          "isn't": 20,
#          'outrageously': 1,
#          'priced.': 1,
#          'their': 62,
#          'job.': 2,
#          'They': 103,
#          'difficult': 20,
#          'pull': 28,
#          'socket': 1,
#          'need': 73,
#          'it,': 63,
#          "that's": 25,
#          'point.': 4,
#          'airplane': 1,
#          'trip': 9,
#          'wanted': 34,
#          'close': 18,
#          'top': 47,
#          'completely': 16,
#          'traveling': 3,
#          '(our': 1,
#          'normal': 7,
#          'lid).': 1,
#          'cup': 35,
#          '(not': 8,
#          'purport': 1,
#          'be),': 1,
#          'leak': 20,
#          'held': 10,
#          'downward': 1,
#          'angle': 2,
#          'upside': 3,
#          'WITHOUT': 1,
#          'lid': 7,
#          'on.': 18,
#          'WITH': 4,
#          'closed,': 2,
#          'all.': 14,
#          'Excellent': 7,
#          'cover!': 3,
#          'polka-dot': 1,
#          'covered': 8,
#          'boppy': 2,
#          'originally': 5,
#          'fabric': 11,
#          'sandpaper.': 1,
#          'Even': 20,
#          "wouldn't": 14,
#          'sleep': 50,
#          'organic': 4,
#          'cover': 50,
#          'jersey': 2,
#          'knit': 4,
#          'super': 41,
#          'soft,': 9,
#          'neutral.': 3,
#          'newborn': 15,
#          'does': 73,
#          'tummy': 10,
#          'face': 19,
#          'rubs': 1,
#          'against': 13,
#          'problems.': 9,
#          'two!': 1,
#          'Highly': 13,
#          'recommended': 13,
#          'Boppy': 5,
#          'covers!': 1,
#          'amazing': 8,
#          'swing!': 1,
#          'relatively': 7,
#          'together': 18,
#          'cradle': 5,
#          'swing': 24,
#          'use.': 27,
#          'switch': 8,
#          'between': 21,
#          'modes': 1,
#          'recline': 8,
#          'upright': 6,
#          'change': 19,
#          'to.': 6,
#          'show': 6,
#          'pretty': 57,
#          'beginning': 3,
#          'enjoy': 15,
#          'real': 21,
#          'soon.': 2,
#          'best': 45,
#          'uses': 9,
#          'power': 3,
#          'cord': 1,
#          'instead': 20,
#          'battery': 11,
#          'only.': 1,
#          'full': 18,
#          'charge': 2,
#          'turn': 30,
#          'mode': 5,
#          'D': 1,
#          'batteries': 9,
#          'outlet.': 1,
#          'regular': 17,
#          'standard': 8,
#          'power!': 1,
#          'A+': 1,
#          'Service': 2,
#          'Product!': 1,
#          'At': 10,
#          'wasnt': 1,
#          'going': 44,
#          'matresses': 1,
#          'resistant': 1,
#          'anyway': 1,
#          "I'm": 91,
#          'glad': 25,
#          'did.': 3,
#          'made': 69,
#          'bedding': 7,
#          'much': 142,
#          'nicer!': 1,
#          'substitute': 1,
#          'your': 112,
#          'child': 66,
#          'sound': 15,
#          'plastic': 37,
#          'bags': 16,
#          'mine.': 1,
#          'entire': 13,
#          'skirt': 4,
#          'same': 32,
#          'crinkle': 7,
#          '7': 20,
#          'staring': 2,
#          "doll's": 1,
#          'eyes.Worth': 1,
#          'cost': 5,
#          'apparently': 1,
#          'say': 30,
#          "she'll": 1,
#          'gets': 39,
#          'older': 14,
#          'son.': 11,
#          'comfortable.': 10,
#          'likes': 31,
#          'much.': 12,
#          'what': 83,
#          'paid.': 1,
#          'product...': 2,
#          'girl': 16,
#          'LOVES': 9,
#          'tummytub': 1,
#          'time,': 10,
#          'home': 17,
#          'hospital': 9,
#          'old.': 22,
#          'high': 35,
#          'chair': 38,
#          'versatile': 2,
#          'convenient,': 3,
#          'highly': 38,
#          'recommend.': 10,
#          'sturdy,': 6,
#          'clean,': 10,
#          'grow': 8,
#          'everyday': 11,
#          'home,': 3,
#          'restuarants,': 1,
#          "Grandpa's": 1,
#          'family': 9,
#          'togethers.': 1,
#          'husband': 41,
#          'sceptic': 1,
#          'showed': 2,
#          'picture': 15,
#          '(it': 3,
#          'look': 33,
#          '"safe").': 1,
#          'impressed': 9,
#          'secure': 12,
#          'straps': 20,
#          '(connecting': 1,
#          'baby).': 3,
#          'tray': 23,
#          'off.': 19,
#          'find': 48,
#          'place': 25,
#          '"one': 1,
#          'thing"': 1,
#          'kitchen.': 1,
#          'Money': 2,
#          'spent!!': 1,
#          'baby.': 30,
#          'product': 81,
#          'made,': 4,
#          'job': 8,
#          'designed': 8,
#          'for.': 10,
#          'foldable': 2,
#          'diaper': 90,
#          'bag.': 22,
#          'purchase': 23,
#          'again.': 11,
#          'sacks': 2,
#          'Aden': 3,
#          '+': 2,
#          'Anais': 2,
#          'them': 175,
#          'S-L.': 1,
#          'While': 5,
#          'believe': 9,
#          'feel': 23,
#          'realistic': 1,
#          'point': 11,
#          '$25-30': 1,
#          'bullet': 1,
#          'each': 22,
#          'size.': 9,
#          'mainly': 3,
#          'climber': 1,
#          'climbing': 2,
#          'crib.': 20,
#          'material': 19,
#          'light,': 3,
#          'enough': 72,
#          'sleeve': 1,
#          'pant': 2,
#          'bottom': 30,
#          "PJ's.": 1,
#          'liked': 24,
#          'stayed': 4,
#          'her,': 3,
#          'opposed': 1,
#          'blankets': 8,
#          'do.': 9,
#          'experienced': 5,
#          'zippers,': 1,
#          'although': 8,
#          'said': 27,
#          'differently.': 1,
#          'keeping': 20,
#          'arrive': 2,
#          'August.': 1,
#          'decals!': 1,
#          'draw': 2,
#          'back': 95,
#          'textured': 3,
#          'walls.': 2,
#          'stick': 8,
#          'Out': 1,
#          'decal': 1,
#          'collection,': 1,
#          'five': 11,
#          'difficulty': 2,
#          'sticking': 2,
#          'though': 40,
#          'bad.': 6,
#          'think': 63,
#          'may': 19,
#          'due': 16,
#          'fact': 26,
#          'packaging': 3,
#          'crease': 1,
#          'slightly': 8,
#          'folded.': 2,
#          'Quinny': 1,
#          'Zapp': 1,
#          'Xtra,': 1,
#          'especially': 15,
#          'colour,': 1,
#          'why': 15,
#          'image': 1,
#          'showing': 3,
#          'four': 16,
#          'wheels': 12,
#          'tripod': 1,
#          'wheel': 6,
#          'structure?': 1,
#          'than': 139,
#          'thought': 29,
#          'would,': 1,
#          'three': 28,
#          'setting': 7,
#          '(music': 1,
#          'tunes,': 1,
#          'ocean': 7,
#          'sounds,': 3,
#          'white': 10,
#          'noise)': 1,
#          'music': 28,
#          "she's": 9,
#          'awake': 3,
#          'sounds': 13,
#          'lull': 1,
#          'wakes': 7,
#          'eat': 10,
#          'middle': 15,
#          'night.': 12,
#          'downside': 3,
#          'quiet': 3,
#          'loud,': 1,
#          'next': 28,
#          'loud.': 1,
#          'nooks': 1,
#          'corners': 1,
#          'have.': 9,
#          'job,': 2,
#          'unit': 6,
#          'lasted': 5,
#          'through': 44,
#          'cleanups.': 1,
#          'am': 91,
#          'satisfied': 13,
#          'Oxo': 1,
#          'brand': 16,
#          'items.': 5,
#          'If': 48,
#          'cleanliness': 1,
#          'godliness,': 1,
#          'should': 17,
#          'right': 73,
#          'hymnal.': 1,
#          'gift': 36,
#          'daughter-in-law,': 1,
#          'gift,': 2,
#          'went': 29,
#          'stroller': 93,
#          'easily,': 5,
#          '6wks,': 1,
#          'early': 9,
#          'info.': 2,
#          '5': 52,
#          'months': 113,
#          'perfectly.It': 1,
#          'strap': 11,
#          'face,': 2,
#          'stars': 24,
#          'item': 38,
#          'cotton': 7,
#          'bumper': 8,
#          'mini': 8,
#          'cribs': 2,
#          'amazingly': 1,
#          'good': 113,
#          'expensive.': 1,
#          'looking': 45,
#          'recreate': 1,
#          'pottery': 2,
#          'barn': 3,
#          'restoration': 1,
#          'hardware': 3,
#          'grey': 1,
#          'ticket': 1,
#          'fraction': 1,
#          'cost.': 5,
#          'Perfect': 11,
#          'needs,': 1,
#          'glide': 1,
#          'easily': 55,
#          'wood': 16,
#          'floors.': 1,
#          'trouble': 15,
#          'carpet': 1,
#          'tile': 4,
#          'wood.': 1,
#          'Easy': 29,
#          'assemble,': 3,
#          'feminine': 1,
#          'toys': 55,
#          'occupied': 3,
#          'buzzing': 1,
#          'house.': 14,
#          'complaint': 18,
#          '34.99': 1,
#          'Ross': 1,
#          'arrived,': 1,
#          '$5': 1,
#          'isnt': 2,
#          'return': 3,
#          'something': 40,
#          'assembled': 4,
#          'Smell': 1,
#          'babies.': 8,
#          'items': 19,
#          'Vulli,': 1,
#          'products': 18,
#          'superior.': 1,
#          'large': 23,
#          'stash': 4,
#          'many': 48,
#          'brands': 8,
#          'diapers,': 7,
#          'elastic': 3,
#          'worn': 1,
#          'almost': 32,
#          'third': 6,
#          'half': 11,
#          'crafty,': 1,
#          'affordable': 5,
#          'diapers': 19,
#          'round': 6,
#          'stash.These': 1,
#          'prints': 3,
#          'cute.': 8,
#          'partial': 1,
#          'print': 5,
#          'gray': 1,
#          'tabs,': 1,
#          'hopefully': 2,
#          'future': 6,
#          'option': 9,
#          'pick': 9,
#          'color': 35,
#          'want.': 2,
#          'gussets': 1,
#          'liner': 6,
#          'helps': 13,
#          'pee': 2,
#          'poop.': 1,
#          'charcoal': 1,
#          'hide': 2,
#          'stains': 4,
#          'bamboo.': 1,
#          'soft': 49,
#          'skin': 5,
#          'soaking': 1,
#          'wet': 10,
#          'being': 46,
#          'soiled,': 1,
#          'Kawaii': 1,
#          'Mom': 1,
#          'Label': 1,
#          'Bamboo': 1,
#          'inserts': 7,
#          'go': 68,
#          'front': 25,
#          'Charlie': 1,
#          'Banana': 1,
#          'less': 23,
#          'likely': 3,
#          'poop': 1,
#          'stuck': 7,
#          'insert': 6,
#          'flap.': 1,
#          'thick': 9,
#          'absorb': 1,
#          'positioning': 1,
#          'snaps': 6,
#          'tabs': 2,
#          'cause': 9,
#          'leaks,': 2,
#          "doesn't.": 1,
#          'prefer': 11,
#          'thee': 1,
#          'positioned': 1,
#          'two': 75,
#          'towards': 4,
#          'faster': 3,
#          'easier': 28,
#          'position.The': 1,
#          'owners': 3,
#          'company': 9,
#          'wonderful': 13,
#          'thanked': 1,
#          'pleasant': 4,
#          'surprise.': 1,
#          'above': 12,
#          'beyond': 4,
#          'happy': 64,
#          'order,': 1,
#          'admirable': 1,
#          'definitely': 45,
#          'appreciated': 1,
#          'fold': 21,
#          'booster': 17,
#          'noticed': 14,
#          'complained': 5,
#          'cracks': 2,
#          'food': 21,
#          'take': 96,
#          'apart': 10,
#          'dishwasher': 5,
#          'directions': 9,
#          '(only': 1,
#          'springs': 2,
#          'rust).': 1,
#          'occasionally': 5,
#          'floor': 15,
#          'wants': 17,
#          '(rub': 1,
#          'crayongs': 1,
#          'paper).': 1,
#          'life': 20,
#          'saver!': 3,
#          "couldn't": 18,
#          'calm': 3,
#          'sleep.': 8,
#          'worked': 32,
#          'EVERY': 2,
#          'TIME.': 1,
#          'daughter.': 13,
#          'She': 79,
#          "son's": 16,
#          'stroller.': 28,
#          'gifts,': 1,
#          'best.': 5,
#          'strong': 13,
#          'multiple': 7,
#          'material.': 5,
#          'lightweight': 10,
#          'marquisette': 2,
#          'blanket': 16,
#          'ideal': 1,
#          'nursing': 7,
#          'cover.': 6,
#          'plenty': 17,
#          'mom': 10,
#          'lay': 11,
#          'time/play': 1,
#          'Of': 9,
#          'course,': 7,
#          'swaddling,': 1,
#          'too,': 5,
#          'skill': 1,
#          'learned.': 1,
#          'Another': 4,
#          'thing': 50,
#          'swaddling': 3,
#          'printed': 2,
#          'attached': 15,
#          'always': 47,
#          'you.I': 1,
#          'showers': 2,
#          'invited': 1,
#          'winter': 1,
#          'baby,': 15,
#          'duo.': 1,
#          'late': 3,
#          'spring': 3,
#          'summer': 3,
#          'blanket.': 6,
#          'beautiful,': 3,
#          'timeless,': 1,
#          'sadly': 1,
#          'read': 23,
#          '2013.': 1,
#          'year!': 1,
#          "can't": 50,
#          ...})

# %%
# 부정 리뷰에 들어있는 단어 빈도수 파악

neg_lst = a_df.loc[a_df['rating']=='neg']['review'].values.tolist()
print(neg_lst[:2])

neg_words = []

for n_sentence in neg_lst:
    neg_words.extend(str(n_sentence).split(' '))

neg_counter = Counter(neg_words)
neg_counter
# Out:
# ['I would have given it 5 stars because I love it, but the day I got it the pink circle on the front came off. Easily glued back on, but I was expecting higher quality. I love that it is only 1 year of statutes and info instead of 5. I never record past 1 anyway.', "THis is a pretty inexpensive night light we bought for our boy's room, it's great but the bulb went out after a few weeks."]
# Counter({'I': 2432,
#          'would': 418,
#          'have': 657,
#          'given': 16,
#          'it': 2039,
#          '5': 55,
#          'stars': 23,
#          'because': 251,
#          'love': 60,
#          'it,': 78,
#          'but': 724,
#          'the': 4519,
#          'day': 30,
#          'got': 113,
#          'pink': 15,
#          'circle': 5,
#          'on': 706,
#          'front': 41,
#          'came': 46,
#          'off.': 25,
#          'Easily': 2,
#          'glued': 5,
#          'back': 161,
#          'on,': 11,
#          'was': 820,
#          'expecting': 12,
#          'higher': 7,
#          'quality.': 16,
#          'that': 922,
#          'is': 1418,
#          'only': 213,
#          '1': 54,
#          'year': 56,
#          'of': 1220,
#          'statutes': 1,
#          'and': 2320,
#          'info': 4,
#          'instead': 31,
#          '5.': 2,
#          'never': 58,
#          'record': 3,
#          'past': 11,
#          'anyway.': 2,
#          'THis': 1,
#          'a': 2096,
#          'pretty': 56,
#          'inexpensive': 6,
#          'night': 19,
#          'light': 39,
#          'we': 310,
#          'bought': 204,
#          'for': 1053,
#          'our': 222,
#          "boy's": 1,
#          'room,': 10,
#          "it's": 211,
#          'great': 118,
#          'bulb': 4,
#          'went': 38,
#          'out': 290,
#          'after': 155,
#          'few': 78,
#          'weeks.': 7,
#          'These': 56,
#          'swaddling': 2,
#          'blankets': 8,
#          'are': 445,
#          'amazingly': 1,
#          'soft,': 9,
#          'my': 687,
#          'baby': 266,
#          'loves': 24,
#          'them.': 46,
#          'But': 68,
#          'one': 335,
#          'encounter': 1,
#          'with': 663,
#          'wedding': 2,
#          'ring': 11,
#          'or': 255,
#          'bit': 54,
#          'Velcro,': 1,
#          "they're": 31,
#          'destroyed.': 1,
#          'In': 38,
#          'fact,': 8,
#          'they': 361,
#          "don't": 189,
#          'even': 151,
#          'wash': 22,
#          'well.': 31,
#          'Ours': 1,
#          'had': 309,
#          'snags': 1,
#          'pills': 1,
#          'before': 77,
#          'ever': 20,
#          'to': 2545,
#          'use': 258,
#          'them,': 21,
#          'just': 359,
#          'from': 252,
#          'washing': 11,
#          'them': 208,
#          '(by': 3,
#          'themselves).For': 1,
#          'price': 60,
#          'these': 190,
#          'blankets,': 1,
#          'there': 119,
#          'absolutely': 11,
#          'no': 147,
#          'way': 94,
#          'should': 76,
#          'be': 464,
#          'ruined': 4,
#          'by': 87,
#          'end': 25,
#          'first': 131,
#          'use.': 32,
#          'Unbelievable!': 1,
#          'Got': 4,
#          'this': 982,
#          'sale': 2,
#          '(thank': 1,
#          'goodness': 1,
#          "didn't": 122,
#          'pay': 26,
#          'full': 18,
#          'price)': 1,
#          'took': 44,
#          '4': 47,
#          'hours': 11,
#          'put': 130,
#          'together.': 11,
#          '': 1584,
#          'Many': 1,
#          'imperfections': 1,
#          'in': 912,
#          'wood,': 2,
#          'including': 5,
#          'crack': 4,
#          'across': 10,
#          'top': 64,
#          'occurred': 2,
#          'painting,': 1,
#          'as': 439,
#          'painted': 4,
#          'over.': 16,
#          'Wish': 4,
#          'stopped': 33,
#          'assembling': 1,
#          'two': 136,
#          'into': 138,
#          'returned': 26,
#          'it.': 189,
#          'JUNK!': 1,
#          'really': 208,
#          'excited': 19,
#          'buy': 125,
#          'despite': 4,
#          'hefty': 2,
#          'tag': 6,
#          'body': 17,
#          'pillow': 30,
#          'during': 14,
#          'pregnancy': 1,
#          'regretted': 1,
#          'retrospect': 1,
#          'wish': 54,
#          'purchased': 70,
#          'snoogie': 1,
#          'perhaps': 9,
#          'wedge': 1,
#          'support': 23,
#          "I'm": 111,
#          'looking': 58,
#          'under': 41,
#          'belly,': 2,
#          'exactly': 14,
#          'where': 66,
#          'padding': 12,
#          'boppy': 5,
#          'pillow.': 7,
#          'It': 339,
#          'gives': 4,
#          'good': 144,
#          'leg': 6,
#          'okay': 9,
#          'cuddle': 1,
#          'with,': 4,
#          'find': 51,
#          'myself': 14,
#          'needing': 5,
#          'small': 56,
#          'belly': 5,
#          'feel': 48,
#          'comfortable.': 8,
#          '29': 1,
#          'weeks': 27,
#          'now,': 11,
#          'definitely': 32,
#          'starting': 8,
#          'uncomfortable': 14,
#          'at': 281,
#          'night.': 9,
#          'bottles': 58,
#          'pump': 42,
#          'store': 24,
#          'breast': 16,
#          'milk': 32,
#          'fridge.': 1,
#          'They': 83,
#          'work': 91,
#          'fit': 101,
#          'Medela': 20,
#          'pump.': 8,
#          'My': 152,
#          'complaint': 9,
#          'oz': 4,
#          'markings': 1,
#          'quickly': 22,
#          'wearing': 11,
#          '9#': 1,
#          'discharge': 1,
#          'hospital': 7,
#          'too': 182,
#          'big': 69,
#          'start': 22,
#          'insert.': 1,
#          '12#': 1,
#          'foot.': 2,
#          'Especially': 1,
#          'cooler': 3,
#          'months': 99,
#          'when': 331,
#          'will': 239,
#          'bundled': 1,
#          'some': 82,
#          'ridiculously': 2,
#          'adorable': 4,
#          'fuzzy': 1,
#          'outerwear,': 1,
#          'thing': 70,
#          "isn't": 48,
#          'necessary.': 2,
#          'long': 56,
#          'high': 51,
#          'head': 52,
#          'pillow/insert': 1,
#          'there.': 13,
#          'Without': 2,
#          'she': 128,
#          'can': 211,
#          'scoot': 1,
#          'low': 12,
#          'enough': 79,
#          'scrunched': 2,
#          'newborn': 13,
#          'Ergo': 7,
#          'her': 154,
#          'head.For': 1,
#          'what': 122,
#          'worth,': 1,
#          'do': 148,
#          'so': 479,
#          'far.': 5,
#          'Every': 8,
#          'time': 129,
#          'falls': 12,
#          'asleep.': 2,
#          'very': 340,
#          'disappointed': 40,
#          'product,': 17,
#          'exorbitant': 1,
#          'considering': 11,
#          'its': 83,
#          'lack': 8,
#          'efficacy': 1,
#          'poor': 19,
#          'quality': 59,
#          'materials.': 3,
#          'Forget': 2,
#          'about': 187,
#          'any': 101,
#          '"nice': 1,
#          'haves"': 1,
#          '-': 136,
#          'little': 154,
#          'thought': 95,
#          'design.The': 1,
#          'product': 151,
#          'does': 128,
#          'not': 756,
#          'meet': 3,
#          'basic': 7,
#          'expectations': 1,
#          'monitor;1.': 1,
#          'Sound': 2,
#          'captured': 1,
#          'intermittently.': 1,
#          '(11': 2,
#          'months)2.': 1,
#          'Poor': 5,
#          'image': 3,
#          'quality3.': 1,
#          'Battery': 1,
#          'life': 6,
#          '~1hr': 1,
#          'soon': 18,
#          'purchase': 39,
#          'keep': 81,
#          'plugged': 7,
#          'in.': 11,
#          'We': 226,
#          'replaced': 13,
#          'battery.': 1,
#          '(7': 2,
#          "months)We've": 1,
#          'been': 92,
#          'had.': 3,
#          'waste': 49,
#          'money.': 36,
#          'basically': 13,
#          'plastic': 68,
#          'discs': 1,
#          'wind': 5,
#          'up': 255,
#          'blind': 1,
#          'cord.': 3,
#          'However,': 51,
#          'you': 523,
#          'place': 28,
#          'disc': 2,
#          'perfect': 20,
#          'center': 9,
#          'cord': 6,
#          'both': 55,
#          'sides.': 7,
#          'If': 96,
#          '&#34;thick&#34;,': 1,
#          'pops': 6,
#          'open': 56,
#          'need': 74,
#          'Also,': 35,
#          'packaging': 7,
#          'yellow,': 1,
#          'discolored': 1,
#          'copyright': 1,
#          'date': 2,
#          "'90s.": 1,
#          'think': 89,
#          'sitting': 20,
#          'around': 81,
#          "someone's": 1,
#          'basement': 2,
#          'twenty': 1,
#          'years.': 9,
#          'cheap': 31,
#          'worth': 56,
#          'dollar.': 1,
#          'First,': 7,
#          'arrived': 15,
#          'were': 167,
#          'smaller': 27,
#          'than': 170,
#          'expected': 9,
#          'organic.': 1,
#          'There': 24,
#          'better': 99,
#          "I've": 64,
#          'kept': 28,
#          'since': 98,
#          "wasn't": 47,
#          'returning.': 2,
#          'i': 111,
#          'like': 297,
#          'toothbrush': 5,
#          'son': 116,
#          'who': 45,
#          '2': 99,
#          'yrs': 2,
#          'old.i': 1,
#          'large': 30,
#          'blue': 12,
#          '(purchased': 1,
#          'elsewhere).The': 1,
#          'reason': 20,
#          'habe': 1,
#          'insists': 1,
#          '&#34;brushing': 1,
#          'his': 106,
#          'teeth&#34;': 1,
#          'himself,': 1,
#          'which': 133,
#          'obviously': 5,
#          'going': 80,
#          'effective.': 2,
#          'So,': 16,
#          'while': 61,
#          'he': 146,
#          '&#34;brushes&#34;': 1,
#          'brush,': 2,
#          'am': 141,
#          'able': 61,
#          'sneak': 1,
#          '&#34;real&#34;': 1,
#          'toothbrush.But': 1,
#          'real': 25,
#          'problem': 47,
#          'point': 13,
#          'me': 163,
#          'writing': 3,
#          'this.....Since': 1,
#          'boy....and...(colors': 1,
#          'may': 53,
#          'vary),': 1,
#          'why': 29,
#          'take': 64,
#          '34%': 1,
#          'chance': 4,
#          'getting': 62,
#          'son?': 1,
#          'Who': 6,
#          'their': 69,
#          'toothbrush?If': 1,
#          'u': 6,
#          'boy,': 1,
#          'suggest': 8,
#          'same': 75,
#          'if': 267,
#          '&#34;colors': 1,
#          'vary&#34;': 1,
#          'On': 10,
#          'item.': 13,
#          't': 3,
#          'makes': 53,
#          'sense': 4,
#          'amazon': 5,
#          'childrens': 1,
#          'items.': 6,
#          'DONT': 2,
#          'BUY!': 1,
#          'item': 48,
#          'trying': 49,
#          'save': 15,
#          'money': 72,
#          'now': 88,
#          'another': 73,
#          'one.': 40,
#          'disgusting,': 1,
#          'soft': 39,
#          'cushion': 7,
#          'absorbs': 1,
#          'everything': 14,
#          'near': 21,
#          'impossible': 22,
#          'get': 277,
#          'rid': 6,
#          'of.': 3,
#          'Smells': 1,
#          'horrible': 12,
#          'throw': 23,
#          'away.': 13,
#          'Only': 10,
#          'part': 56,
#          'other': 169,
#          'piece': 38,
#          'step': 11,
#          'stool.': 2,
#          'This': 234,
#          'cute': 38,
#          'doll': 4,
#          'lots': 11,
#          'tactile': 1,
#          'simulation,': 1,
#          'education.': 1,
#          'Soft': 4,
#          'hold': 61,
#          'touch': 12,
#          'sleep': 26,
#          'with.': 7,
#          'Fault,i': 1,
#          'maybe': 28,
#          'an': 153,
#          'alternate': 1,
#          'spelling': 1,
#          'bur': 1,
#          'friends': 4,
#          'IGOR': 1,
#          'eeYORE.not': 1,
#          'clearly': 12,
#          'marked': 1,
#          'blown': 1,
#          'south': 1,
#          'american': 1,
#          'import.usa': 1,
#          'packaged': 3,
#          'WAS': 1,
#          'available': 6,
#          'cost': 14,
#          'Useless': 2,
#          'child': 67,
#          'did': 92,
#          'much': 163,
#          'next': 16,
#          'without': 59,
#          'harness.': 3,
#          'Took': 2,
#          'effort!': 1,
#          'Gave': 1,
#          'away': 34,
#          'already.': 3,
#          'Which': 6,
#          'friend': 8,
#          'stated': 8,
#          'useless,': 3,
#          'too.': 12,
#          'chair': 71,
#          'three': 36,
#          'years': 24,
#          'ago': 9,
#          'means': 11,
#          'suffered': 2,
#          'finished': 5,
#          'cleaning': 8,
#          'reinstalling': 1,
#          'car': 93,
#          'whole': 23,
#          'process': 6,
#          'has': 201,
#          'frustrated': 7,
#          'terribly': 9,
#          'designed': 15,
#          'over-priced,': 1,
#          'ugly': 2,
#          'chair.': 14,
#          'posted': 3,
#          'Amazon': 19,
#          'review': 23,
#          'although': 14,
#          'ago,': 5,
#          'compelled': 1,
#          'spare': 4,
#          'parents': 6,
#          'grief': 1,
#          'cause': 10,
#          'you.': 8,
#          'Please,': 2,
#          'Parents': 1,
#          'busy': 5,
#          'dealing': 6,
#          'all': 220,
#          'challenges': 1,
#          'parenting,': 1,
#          'last': 45,
#          'poorly': 10,
#          'equipment': 1,
#          'then': 114,
#          'precious': 2,
#          'it.-': 2,
#          'Overpriced.-': 1,
#          'Very': 32,
#          'heavy.': 3,
#          'Forger': 1,
#          'taking': 15,
#          'anywhere': 5,
#          'dread': 1,
#          'removing': 5,
#          'ugly.': 1,
#          'Looks': 3,
#          'sofa': 2,
#          'your': 190,
#          'grandmother': 1,
#          'buy-': 1,
#          'Straps': 1,
#          'always': 47,
#          'tangling': 1,
#          'through': 68,
#          'tension': 6,
#          'pulls-': 1,
#          'difficult': 49,
#          'install.': 3,
#          'The': 541,
#          'seat': 217,
#          'fasteners': 2,
#          'click': 8,
#          'upside': 7,
#          'down': 86,
#          'pull': 27,
#          'cant': 12,
#          'sufficient': 2,
#          'further': 6,
#          'tangle': 2,
#          'straps-': 1,
#          'Fabric': 2,
#          'clean': 31,
#          'soaked': 5,
#          'upholstery': 1,
#          'overnight': 3,
#          'detergent,': 1,
#          'washed': 19,
#          'twice': 10,
#          'still': 111,
#          'smells': 4,
#          'vomit.-': 1,
#          'takes': 22,
#          'huge': 12,
#          'amount': 11,
#          'real-estate': 1,
#          'car.': 11,
#          'drive': 2,
#          'Honda': 2,
#          'CR-V,': 1,
#          'seats': 32,
#          'installed': 12,
#          'more': 212,
#          'room': 41,
#          'anything': 33,
#          'Turns': 1,
#          'five': 8,
#          'seater': 1,
#          'seater.': 1,
#          'Had': 2,
#          'known': 9,
#          'Porsche-': 1,
#          'Our': 18,
#          '3': 85,
#          'old': 129,
#          'boy': 10,
#          'complains': 3,
#          'lap': 5,
#          'belt': 18,
#          'prickly': 1,
#          'cleaned': 6,
#          'several': 24,
#          'times': 48,
#          'dont': 18,
#          'know': 53,
#          'about.': 3,
#          'mean': 12,
#          'comfortable.This': 1,
#          'come': 48,
#          'machine': 13,
#          'travel': 13,
#          'product.Please': 1,
#          'consider': 5,
#          'carefully,': 3,
#          'theres': 3,
#          'plenty': 2,
#          'products': 15,
#          'received': 48,
#          'gift': 26,
#          'shortly': 1,
#          'born.': 4,
#          'wonderful': 8,
#          'light.': 3,
#          'loved': 39,
#          'portability': 2,
#          'battery': 21,
#          'life.': 3,
#          'ideal': 3,
#          'travel.': 3,
#          'colored': 6,
#          'lights': 11,
#          'bright': 10,
#          'change': 23,
#          'diaper': 73,
#          'middle': 16,
#          'us': 36,
#          'sleeping.After': 1,
#          '9': 15,
#          'use,': 11,
#          'working': 36,
#          'day.': 9,
#          'No': 21,
#          'signs': 2,
#          'wear,': 1,
#          'dropped,': 3,
#          'contact': 9,
#          'water': 62,
#          '(or': 8,
#          'drool).': 1,
#          'idea': 23,
#          'happened.I': 1,
#          'ready': 8,
#          'replace': 18,
#          'read': 47,
#          'consumer': 3,
#          'reviews': 52,
#          'complained': 3,
#          'theirs': 1,
#          'couple': 37,
#          'months.': 20,
#          'lucky': 4,
#          'ours.We': 1,
#          'ours': 5,
#          'similar': 11,
#          'style': 3,
#          '(Kinderglo)': 1,
#          'since,': 1,
#          'over': 97,
#          'now.': 10,
#          'ton': 7,
#          'prior': 4,
#          'daughters': 7,
#          'arrival.': 1,
#          'Like': 7,
#          'everyone': 9,
#          'else': 23,
#          'found': 47,
#          'VERY': 20,
#          'cute.': 5,
#          'She': 31,
#          'began': 6,
#          'leaking': 10,
#          'ago.....': 1,
#          'rim.': 1,
#          'When': 69,
#          'unscrewed': 1,
#          'try': 64,
#          're-tighten': 1,
#          'discovered': 10,
#          'clear': 7,
#          'bottle': 52,
#          'cracked!': 1,
#          'checked': 8,
#          '8': 20,
#          'problem!!!!': 1,
#          'Some': 5,
#          'lost': 11,
#          'pieces': 31,
#          'plastic!': 1,
#          'see': 85,
#          'how': 76,
#          'noticed': 16,
#          'before,': 4,
#          'happened.': 3,
#          'DO': 9,
#          'dishwasher': 6,
#          '(as': 4,
#          'directed),': 1,
#          'scrub': 1,
#          'each': 44,
#          'individual': 3,
#          'hand??': 1,
#          'do,': 3,
#          'kuddos': 1,
#          'you,': 9,
#          'probably': 33,
#          'safest': 1,
#          'way.': 9,
#          'As': 37,
#          'else,': 3,
#          'nipple': 30,
#          'held': 10,
#          'air': 15,
#          'bubbles,': 1,
#          'hard': 92,
#          'suck': 9,
#          'from.': 6,
#          'daughter': 80,
#          'too,': 3,
#          'bad': 39,
#          'gas': 7,
#          'colic': 2,
#          'bottles.': 15,
#          'switched': 8,
#          'Playtex': 6,
#          'nurser': 1,
#          'nipple,': 1,
#          'plus': 15,
#          'bag': 57,
#          'squeeze': 10,
#          'extra': 18,
#          'feeding': 12,
#          'child.': 15,
#          'advice......': 1,
#          'let': 27,
#          'tell': 13,
#          'works': 49,
#          'best': 32,
#          'her.': 10,
#          'What': 26,
#          'worked': 44,
#          'child,': 7,
#          'might': 35,
#          'being': 47,
#          'disaster': 1,
#          'another.': 4,
#          'hoping': 9,
#          'help': 34,
#          'picked': 6,
#          'wanted': 47,
#          'hands': 16,
#          'free': 17,
#          'things': 33,
#          'live': 12,
#          'South': 1,
#          'Florida': 1,
#          'Babybjorn': 2,
#          'Air': 2,
#          'Carrier': 2,
#          'seemed': 27,
#          'idea.': 6,
#          'easy': 73,
#          'him': 67,
#          'time.': 31,
#          'carrier': 22,
#          'itself': 16,
#          'rough': 9,
#          "son's": 23,
#          'red': 6,
#          'rubbing': 3,
#          'fabric': 45,
#          'openings.': 2,
#          'After': 41,
#          'carrying': 8,
#          '20': 12,
#          'mins': 5,
#          'sore': 3,
#          "couldn't": 30,
#          'long.': 7,
#          'Overall,': 7,
#          'OK': 2,
#          'me,': 16,
#          'ended': 29,
#          'returning': 22,
#          'hurt': 4,
#          'hot': 21,
#          'using': 97,
#          'this.': 32,
#          'gets': 57,
#          'dirty': 19,
#          'fast.': 5,
#          'Excess': 1,
#          'build': 4,
#          'lot': 48,
#          'cups': 34,
#          'drying': 7,
#          'clips': 4,
#          'well...at': 1,
#          'first.': 9,
#          'Then': 15,
#          'eventually': 12,
#          'glue': 4,
#          'holds': 12,
#          'together': 16,
#          'comes': 41,
#          'apart.': 6,
#          'break': 13,
#          'short': 22,
#          'while.': 4,
#          'weak.': 1,
#          'could': 132,
#          'tight': 23,
#          'onto': 20,
#          'wall.': 8,
#          'installing,': 1,
#          'decided': 32,
#          'return.': 6,
#          'Stroller': 2,
#          'flips': 2,
#          'remove': 17,
#          'itStroller': 1,
#          'flipped': 3,
#          'today': 9,
#          'actually': 66,
#          'itWhite': 1,
#          'color': 28,
#          'dirtyCannot': 1,
#          'storage': 14,
#          'mesh': 13,
#          'area': 23,
#          'underneathDo': 1,
#          'order': 11,
#          'sent': 28,
#          'box': 22,
#          'ship': 8,
#          'refrigerator!!': 1,
#          'To': 11,
#          'add': 9,
#          'insult': 1,
#          'injury': 2,
#          '...': 8,
#          'WRONG': 1,
#          'ITEM': 1,
#          'sent!.': 1,
#          'Instead': 8,
#          'genie': 6,
#          'ELITE,': 1,
#          'useless': 21,
#          'mini': 6,
#          '(that': 5,
#          'approx': 1,
#          '10': 25,
#          'diapers': 31,
#          'it)': 3,
#          'pkgs': 2,
#          'refills.': 2,
#          'Cust.service': 1,
#          'contacted': 10,
#          'days': 26,
#          'false': 2,
#          'advertisement': 1,
#          'cannot': 30,
#          'send': 26,
#          'ELITE': 1,
#          'all(even': 1,
#          'tho': 2,
#          'currently': 7,
#          'advertised': 3,
#          'shopping)!': 1,
#          'So': 60,
#          'resolution': 1,
#          'return': 43,
#          'creditand': 1,
#          'look': 50,
#          'elite': 1,
#          'elsewhere.(Really??)...': 1,
#          'hunt': 1,
#          'another!': 1,
#          'many': 38,
#          'levels!I': 1,
#          'encountered': 2,
#          'geez...after': 1,
#          'resolving': 1,
#          'believe': 14,
#          'xmas': 2,
#          'shopping': 7,
#          'elsewhere': 2,
#          'liked': 40,
#          'Purchased': 4,
#          'lid': 19,
#          'silicone': 4,
#          'sleeve,': 1,
#          'tall': 19,
#          'Mason': 1,
#          'jar': 2,
#          'gave': 32,
#          'kids': 44,
#          '(4': 1,
#          '2yo).': 1,
#          'hardest': 1,
#          'finding': 5,
#          'opening': 20,
#          'finally': 14,
#          'did,': 4,
#          'almost': 42,
#          'spilled': 4,
#          'themselves.': 1,
#          'lids': 10,
#          'leak': 16,
#          'screws': 22,
#          'part.': 6,
#          'off,': 14,
#          'mason': 2,
#          'jars': 2,
#          'donated': 1,
#          'lid/sleeve': 1,
#          'charity.': 1,
#          "I'd": 37,
#          'say': 47,
#          'recommend': 56,
#          'Lifefactory': 1,
#          'glass': 16,
#          'sippy': 18,
#          'top,': 8,
#          'removed': 8,
#          'valve': 6,
#          'less': 46,
#          'spilling.': 1,
#          'dissapointed.': 1,
#          'matter': 12,
#          'fall': 32,
#          'off': 123,
#          'continuosly.': 1,
#          'deffinately': 1,
#          'recommend.': 4,
#          'NOT': 55,
#          'BUY': 4,
#          'THIS.': 2,
#          'screamed': 1,
#          'bloody': 1,
#          'murder': 1,
#          'every': 47,
#          'AND': 11,
#          'stroller.': 25,
#          'hated': 4,
#          'strapped': 5,
#          'until': 43,
#          'Eddie': 2,
#          'Bauer': 3,
#          'Britax': 22,
#          'FALLS': 1,
#          'ASLEEP': 1,
#          'car!': 1,
#          'Something': 3,
#          "he's": 22,
#          'done': 14,
#          ...})

# %% [markdown]
# #### 긍정/부정 확률 계산
#
#     P(positive), N(negative)
#     - 긍정, 부정 리뷰를 1,000개씩 가져왔으므로 긍정,부정의 확률은 각각 0.5, 0.5임

# %%
percent_pos, percent_neg = 0.5, 0.5

# %% [markdown]
# #### 긍정일 때의 리뷰의 조건부 확률 계산
#
#     P(review|positive)
#     해당 리뷰들의 각 단어들이 모두 독립이라는 것을 가정하고, 각 단어들이 긍정 리뷰에 나타날 확률
#     예를 들어 'These are great' 라면 P(These|positive) * P(are|positive) * P(great|positive)

# %%
review_case4=  'These are great'

# 전체 긍정, 부정의 단어 수
total_pos = sum(pos_counter.values())
total_neg = sum(neg_counter.values())

review_given_pos = 1
review_given_neg = 1

# smoothing (스무딩) : 단어가 기존의 리뷰에 존재하지 않는 경우 확률이 0이 되므로 1을 더해줌

for word in review_case4.split(' '):
    review_given_pos *= (pos_counter[word] + 1) / (total_pos + len(pos_counter))
    review_given_neg *= (neg_counter[word]+1)/ (total_neg + len(neg_counter))

print(review_given_pos)
print(review_given_neg)
# Out:
# 8.30035611046729e-09
# 2.656093835438738e-09

# %% [markdown]
# #### 분류하기
#
#     P(positive|review) 와 P(negative|reveiw) 계산
#     - 임의의 리뷰가 주어졌을 때, 해당 리뷰가 긍정적인지 부정적인지 분류
#     - 최종확률은 pos가 더 크기 때문에 These are great 리뷰는 긍정으로 분류 될 것

# %%
pos = review_given_pos * percent_pos
neg = review_given_neg * percent_neg

print(pos)
print(neg)
# Out:
# 4.150178055233645e-09
# 1.328046917719369e-09

# %% [markdown]
# ---------

# %% [markdown]
#       - 아마존 전체 데이터를 가지고 navie bayes classification 해보기

# %%
all_data = data.copy()

# %%
all_data['rating'] = all_data['rating'].apply(lambda x: 'pos' if int(x)>=4 else 'neg')
display(all_data.head(3))
# Out:
#                                   name  \
# 0             Planetwise Flannel Wipes
# 1                Planetwise Wipe Pouch
# 2  Annas Dream Full Quilt with 2 Shams
#
#                                               review rating
# 0  These flannel wipes are OK, but in my opinion ...    neg
# 1  it came early and was not disappointed. i love...    pos
# 2  Very soft and comfortable and warmer than it l...    pos

# %%
all_data = all_data.dropna()
all_data.isnull().sum()
# Out:
# name      0
# review    0
# rating    0
# dtype: int64

# %%
all_data['rating'].value_counts()
# Out:
# pos    139318
# neg     43066
# Name: rating, dtype: int64

# %%
all_p_data = all_data.loc[all_data['rating']=='pos'].sample(43000)
all_n_data = all_data.loc[all_data['rating']=='neg'].sample(43000)

# %%
all_df = pd.concat([all_p_data, all_n_data]).reset_index(drop=True)
all_df.head(3)
# Out:
#                                                 name  \
# 0  DwellStudio&reg; for Target&reg;Silver Lake Co...
# 1  Lamaze Play &amp; Grow Mortimer the Moose Take...
# 2  Trio of Sunshine&reg; Polishing Cloths for Ste...
#
#                                               review rating
# 0  I really love this crib. It went together easi...    pos
# 1  I bought this for the coming arrival of my bab...    pos
# 2  I really like these. They work really well. Th...    pos

# %%
all_review = all_df['review'].values.astype('U')
all_review
# Out:
# array(["I really love this crib. It went together easily and is working very well for us. The material is nice and strong, and the particle board is kept to a minimum. The only issue I have is that at the time we got it, the description said it came with the conversion rails. It doesn't.Amazon seems to have corrected this issue, but finding the conversion parts was pretty tough. I had to chase down the manufacturer (Foremost Group, not Dwell Studio or Target) and order it over the phone for an extra $80.I did that here: [...]We also got the matching changing table and changed the knobs out with some decorative ones from Anthropologie, which really gives it some character and made it sort of unique. Quality stuff.",
#        "I bought this for the coming arrival of my baby boy. It's really cute and colorful, but pretty big. I couldn't hang it on my infant carrier without it whacking my kid in the face.",
#        'I really like these. They work really well. They have cleaned the tarnish off a lot of my jewelry. I sell jewelry and have been recommending these to my customers!',
#        ...,
#        "This bungee is awesome because you can wash it in the sink with soap and water and it doesn't absorb all of the food and liquids that seem to be constantly falling from my babies mouth.  It  feels/seems much more hygienic then the standard cloth straps.  My two issues are 1. The strap is too long... It's constantly getting in the way and dragging on the floor whenever my babe bends down or climbs something. 2. I have had this problem with all pacifier clips so it probably  isn't product specific, but the clips always seem to loose their ability to grip very quickly. I will attach it, but it has no clench and quickly falls off.",
#        "the first one I received was damaged and this was not due to the packaging.  I didn't notice it as it was the binding but the person receiving it as a gift did so it wasn't good.  I will say that exchanging it was painless and free.  All in all, it's cute and I love that it can be so personalized and I think the mom to be liked it for the same reasons.  They need to do some quality control as I read several reviews similar to mine.",
#        'I purchased this toy for my son after reading all the reviews about how great the suction is. But it turns out, its not true in my case. The suction easily comes off when my son pulls it. Much worse he puts it on the floor immediately. Its only matter of time before this thing falls apart... So disappointed!!'],
#       dtype='<U14130')

# %%
countvectorizer = CountVectorizer()
countvectorizer.fit(all_review)
countvectorizer
# Out:
# CountVectorizer()

# %%
countvectorizer.vocabulary_
# Out:
# {'really': 33829,
#  'love': 25097,
#  'this': 42365,
#  'crib': 11384,
#  'it': 22750,
#  'went': 46422,
#  'together': 42896,
#  'easily': 14651,
#  'and': 3538,
#  'is': 22682,
#  'working': 47157,
#  'very': 45500,
#  'well': 46391,
#  'for': 17594,
#  'us': 45022,
#  'the': 41980,
#  'material': 25874,
#  'nice': 28103,
#  'strong': 40355,
#  'particle': 30272,
#  'board': 6496,
#  'kept': 23428,
#  'to': 42836,
#  'minimum': 26582,
#  'only': 29079,
#  'issue': 22726,
#  'have': 20063,
#  'that': 41957,
#  'at': 4409,
#  'time': 42667,
#  'we': 46232,
#  'got': 19041,
#  'description': 12693,
#  'said': 36008,
#  'came': 7959,
#  'with': 46922,
#  'conversion': 10729,
#  'rails': 33563,
#  'doesn': 13844,
#  'amazon': 3383,
#  'seems': 36742,
#  'corrected': 10908,
#  'but': 7711,
#  'finding': 16937,
#  'parts': 30293,
#  'was': 46066,
#  'pretty': 32353,
#  'tough': 43162,
#  'had': 19694,
#  'chase': 8688,
#  'down': 14049,
#  'manufacturer': 25671,
#  'foremost': 17629,
#  'group': 19458,
#  'not': 28414,
#  'dwell': 14545,
#  'studio': 40412,
#  'or': 29257,
#  'target': 41502,
#  'order': 29290,
#  'over': 29652,
#  'phone': 30944,
#  'an': 3505,
#  'extra': 16245,
#  '80': 1838,
#  'did': 13019,
#  'here': 20374,
#  'also': 3294,
#  'matching': 25863,
#  'changing': 8623,
#  'table': 41317,
#  'changed': 8614,
#  'knobs': 23703,
#  'out': 29505,
#  'some': 38709,
#  'decorative': 12270,
#  'ones': 29044,
#  'from': 18017,
#  'anthropologie': 3714,
#  'which': 46549,
#  'gives': 18775,
#  'character': 8646,
#  'made': 25371,
#  'sort': 38839,
#  'of': 28839,
#  'unique': 44500,
#  'quality': 33314,
#  'stuff': 40420,
#  'bought': 6851,
#  'coming': 9899,
#  'arrival': 4149,
#  'my': 27564,
#  'baby': 4899,
#  'boy': 6940,
#  'cute': 11810,
#  'colorful': 9742,
#  'big': 6049,
#  'couldn': 11017,
#  'hang': 19879,
#  'on': 29016,
#  'infant': 21898,
#  'carrier': 8253,
#  'without': 46958,
#  'whacking': 46472,
#  'kid': 23490,
#  'in': 21585,
#  'face': 16350,
#  'like': 24542,
#  'these': 42225,
#  'they': 42267,
#  'work': 47140,
#  'cleaned': 9264,
#  'tarnish': 41511,
#  'off': 28846,
#  'lot': 25049,
#  'jewelry': 23031,
#  'sell': 36805,
#  'been': 5763,
#  'recommending': 34104,
#  'customers': 11791,
#  'enough': 15305,
#  'fit': 17063,
#  'just': 23280,
#  'edges': 14787,
#  'are': 4021,
#  'too': 42995,
#  'close': 9416,
#  'difficult': 13089,
#  'put': 33232,
#  'works': 47170,
#  'read': 33772,
#  'tons': 42991,
#  'reviews': 35273,
#  'product': 32609,
#  'hesitant': 20415,
#  'buy': 7769,
#  'loved': 25100,
#  'son': 38753,
#  'slept': 38051,
#  'sleep': 38003,
#  'sacks': 35929,
#  'every': 15772,
#  'night': 28150,
#  'till': 42656,
#  'felt': 16751,
#  'safe': 35958,
#  'give': 18769,
#  'him': 20530,
#  'blanket': 6283,
#  'actually': 2495,
#  'purchased': 33126,
#  'daughter': 12044,
#  'shower': 37420,
#  'drank': 14136,
#  'our': 29488,
#  'punch': 33071,
#  'them': 42088,
#  'straw': 40203,
#  'ha': 19674,
#  'if': 21315,
#  'you': 47610,
#  'use': 45043,
#  'purpose': 33184,
#  'intended': 22343,
#  'sure': 40937,
#  'can': 8007,
#  'go': 18903,
#  'wrong': 47344,
#  'brand': 7016,
#  'name': 27663,
#  'has': 20016,
#  'around': 4115,
#  'forever': 17643,
#  'fact': 16385,
#  'bpa': 6957,
#  'free': 17856,
#  'great': 19284,
#  'happy': 19927,
#  'fun': 18154,
#  'stroller': 40322,
#  'when': 46524,
#  'running': 35857,
#  'even': 15731,
#  'seem': 36734,
#  'as': 4197,
#  'pushing': 33227,
#  'skeptic': 37886,
#  'about': 2176,
#  'paying': 30444,
#  'much': 27362,
#  'glad': 18785,
#  'concern': 10242,
#  'bulkiness': 7489,
#  'folded': 17479,
#  'wheels': 46513,
#  'attached': 4452,
#  'room': 35640,
#  'anything': 3774,
#  'else': 15033,
#  'yet': 47566,
#  'connect': 10394,
#  'two': 43943,
#  'cameras': 7974,
#  'monitor': 27018,
#  'so': 38550,
#  'report': 34789,
#  'specifically': 39027,
#  'am': 3350,
#  'see': 36718,
#  'never': 28022,
#  'problem': 32531,
#  'already': 3279,
#  'using': 45110,
#  'last': 24022,
#  'eighteen': 14888,
#  'months': 27088,
#  'hopefully': 20806,
#  'will': 46760,
#  'year': 47520,
#  'old': 28962,
#  'loves': 25116,
#  'bedding': 5716,
#  'although': 3325,
#  'he': 20118,
#  'movie': 27317,
#  'still': 39945,
#  'slightly': 38090,
#  'afraid': 2841,
#  'characters': 8650,
#  'bottom': 6827,
#  'sheet': 37179,
#  'think': 42327,
#  'thought': 42421,
#  'would': 47232,
#  'come': 9822,
#  'alive': 3154,
#  'same': 36057,
#  'held': 20302,
#  'true': 43672,
#  'buzz': 7784,
#  'lightyear': 24535,
#  'pillow': 31099,
#  'within': 46948,
#  'few': 16808,
#  'days': 12094,
#  'fine': 16942,
#  'adorable': 2681,
#  'were': 46427,
#  'easy': 14685,
#  'install': 22216,
#  'far': 16509,
#  'done': 13910,
#  'trick': 43540,
#  'keeping': 23390,
#  'coffee': 9598,
#  'corners': 10884,
#  'look': 24951,
#  'better': 5970,
#  'than': 41936,
#  'expected': 16056,
#  'do': 13804,
#  'concerns': 10245,
#  'how': 20956,
#  'stay': 39762,
#  'someone': 38719,
#  'tried': 43556,
#  'peel': 30562,
#  'since': 37719,
#  're': 33749,
#  'by': 7797,
#  'double': 14005,
#  'sided': 37525,
#  'strips': 40301,
#  'tape': 41480,
#  'll': 24791,
#  'awesome': 4725,
#  'worth': 47211,
#  'price': 32391,
#  'beat': 5633,
#  'snaps': 38393,
#  'kick': 23476,
#  'up': 44888,
#  'toss': 43110,
#  'practical': 32071,
#  'excellent': 15892,
#  'their': 42072,
#  'first': 17027,
#  'life': 24462,
#  'enjoy': 15282,
#  'resting': 35051,
#  'does': 13841,
#  'attach': 4448,
#  'everything': 15789,
#  'car': 8140,
#  'swing': 41170,
#  'play': 31365,
#  'pen': 30608,
#  'gave': 18491,
#  'hold': 20670,
#  'toys': 43234,
#  'pull': 33009,
#  'strings': 40292,
#  'once': 29020,
#  'ours': 29497,
#  'started': 39703,
#  'doing': 13865,
#  'back': 5046,
#  'velcro': 45368,
#  'wash': 46075,
#  'bright': 7185,
#  'colors': 9755,
#  'folds': 17496,
#  'perfectly': 30701,
#  'fits': 17073,
#  'into': 22502,
#  'storage': 40069,
#  'compartment': 10039,
#  'needed': 27883,
#  'perfect': 30689,
#  'many': 25692,
#  'lights': 24512,
#  'light': 24490,
#  'make': 25465,
#  'subtle': 40577,
#  'glow': 18861,
#  'wish': 46897,
#  'one': 29029,
#  'color': 9731,
#  'options': 29245,
#  'white': 46617,
#  'blue': 6444,
#  'green': 19321,
#  'fan': 16480,
#  'red': 34187,
#  'rainbow': 33567,
#  'diaper': 12960,
#  'pants': 30160,
#  'underwear': 44314,
#  'covers': 11115,
#  'recently': 33970,
#  'potty': 31988,
#  'training': 43310,
#  '100': 49,
#  'mess': 26306,
#  'accidents': 2322,
#  'she': 37149,
#  'having': 20078,
#  'clean': 9248,
#  'less': 24370,
#  'protecting': 32845,
#  'furniture': 18235,
#  'reason': 33861,
#  'didn': 13028,
#  'five': 17086,
#  'stars': 39694,
#  'because': 5685,
#  'leg': 24288,
#  'holes': 20689,
#  'bit': 6180,
#  'small': 38227,
#  'shields': 37244,
#  'bubbles': 7356,
#  'keep': 23384,
#  'screen': 36470,
#  'hand': 19783,
#  'prints': 32476,
#  'somewhat': 38743,
#  'pleased': 31442,
#  'item': 22785,
#  'friend': 17959,
#  'her': 20365,
#  'birthday': 6168,
#  'especially': 15589,
#  'project': 32684,
#  'could': 11013,
#  'wasn': 46125,
#  'another': 3682,
#  'toy': 43216,
#  'looking': 24958,
#  'portability': 31833,
#  'fold': 17473,
#  'bag': 5137,
#  'yes': 47562,
#  'its': 22825,
#  'kind': 23561,
#  'home': 20713,
#  'usage': 45032,
#  'trips': 43613,
#  'going': 18948,
#  'etc': 15660,
#  'his': 20594,
#  'wife': 46726,
#  'military': 26490,
#  'apo': 3835,
#  'address': 2576,
#  'times': 42694,
#  'hard': 19943,
#  'getting': 18658,
#  'packages': 29966,
#  'received': 33955,
#  'set': 36976,
#  'quickly': 33399,
#  'excited': 15925,
#  'absolutely': 2210,
#  'toddler': 42869,
#  'best': 5949,
#  'safety': 35984,
#  'whoever': 46655,
#  'inveted': 22573,
#  'genius': 18579,
#  'found': 17754,
#  'monkey': 27043,
#  'butt': 7729,
#  'powder': 32031,
#  'babies': 4890,
#  'complain': 10082,
#  'applying': 3906,
#  'rash': 33664,
#  'completely': 10110,
#  'clear': 9307,
#  'exactly': 15851,
#  'what': 46481,
#  'picture': 31033,
#  'negative': 27909,
#  'be': 5586,
#  'base': 5395,
#  'should': 37388,
#  'self': 36801,
#  'leveling': 24396,
#  'right': 35420,
#  'now': 28499,
#  'seat': 36610,
#  'rear': 33844,
#  'facing': 16375,
#  'must': 27527,
#  'installed': 22227,
#  'level': 24393,
#  'position': 31888,
#  'however': 20963,
#  'vehicle': 45354,
#  'add': 2541,
#  'rolled': 35605,
#  'towel': 43190,
#  'pool': 31754,
#  'tool': 43002,
#  'achieve': 2407,
#  'levelness': 24398,
#  'seeking': 36731,
#  'case': 8316,
#  'then': 42127,
#  'designed': 12733,
#  'adjustable': 2634,
#  'adding': 2558,
#  'tacky': 41346,
#  'worst': 47206,
#  'seemingly': 36740,
#  'unsafe': 44707,
#  'kids': 23528,
#  'need': 27879,
#  'expecting': 16061,
#  'again': 2871,
#  'know': 23717,
#  'patterns': 30410,
#  'doubt': 14019,
#  'share': 37116,
#  'botique': 6787,
#  'therefore': 42183,
#  'thinner': 42339,
#  'don': 13901,
#  'mind': 26541,
#  'summer': 40735,
#  'anyway': 3782,
#  'pillows': 31105,
#  'becuase': 5707,
#  'safer': 35976,
#  'easier': 14644,
#  'youngest': 47631,
#  'similar': 37662,
#  'years': 47527,
#  '17': 473,
#  'mentions': 26256,
#  'dog': 13853,
#  'ate': 4413,
#  'ago': 2924,
#  'easter': 14680,
#  'basket': 5435,
#  'cried': 11406,
#  'good': 18974,
#  'gunds': 19600,
#  'help': 20320,
#  'thank': 41942,
#  'money': 26993,
#  'spend': 39077,
#  'your': 47639,
#  'high': 20471,
#  'maintenance': 25453,
#  'thing': 42312,
#  'likes': 24563,
#  've': 45324,
#  'nearly': 27817,
#  'get': 18645,
#  'constructed': 10534,
#  'rolls': 35615,
#  'little': 24755,
#  'resistance': 34950,
#  'handle': 19816,
#  'makes': 25473,
#  'comfortable': 9846,
#  'tall': 41426,
#  'parents': 30232,
#  'grandma': 19179,
#  'bulky': 7493,
#  'more': 27160,
#  'manageable': 25542,
#  'loading': 24816,
#  'unloading': 44562,
#  'served': 36949,
#  'almost': 3246,
#  'four': 17764,
#  'say': 36210,
#  'warmth': 46028,
#  'provides': 32896,
#  'highly': 20495,
#  'recommend': 34094,
#  'roomy': 35662,
#  'used': 45054,
#  'transport': 43384,
#  'todays': 42864,
#  'cold': 9639,
#  'weather': 46269,
#  'nursing': 28603,
#  'cover': 11103,
#  'design': 12718,
#  'inside': 22167,
#  'cloth': 9441,
#  'burp': 7650,
#  'insert': 22154,
#  'pacifier': 29937,
#  'sometimes': 38736,
#  'stops': 40066,
#  'feeding': 16709,
#  'other': 29439,
#  'solid': 38682,
#  'black': 6229,
#  'take': 41395,
#  'space': 38905,
#  'portable': 31836,
#  'biodegradeability': 6133,
#  'bonus': 6633,
#  'potties': 31984,
#  'child': 8871,
#  'wanted': 45995,
#  'motif': 27228,
#  'despite': 12782,
#  'seeming': 36739,
#  'complicated': 10129,
#  'quick': 33393,
#  'fabric': 16330,
#  'stretchy': 40271,
#  'breathable': 7123,
#  'both': 6775,
#  'me': 26043,
#  'husband': 21139,
#  'size': 37853,
#  'all': 3161,
#  'unlike': 44551,
#  'carriers': 8255,
#  'knock': 23704,
#  'instructions': 22276,
#  'warn': 46029,
#  'heads': 20151,
#  'leaning': 24216,
#  'forward': 17736,
#  'chest': 8816,
#  'explain': 16139,
#  'prevent': 32365,
#  'signs': 37596,
#  'result': 35101,
#  'paranoid': 30210,
#  'while': 46563,
#  'girl': 18753,
#  'combi': 9807,
#  'activity': 2487,
#  'walker': 45922,
#  'took': 43000,
#  'hour': 20918,
#  'looks': 24966,
#  'beautiful': 5648,
#  'pieces': 31054,
#  'favorite': 16611,
#  'want': 45992,
#  'ever': 15757,
#  'soft': 38609,
#  'comes': 9830,
#  'cloud': 9459,
#  'noise': 28284,
#  'machine': 25344,
#  'removed': 34659,
#  'nothing': 28444,
#  'things': 42321,
#  'believe': 5845,
#  'waited': 45889,
#  'long': 24922,
#  'britax': 7222,
#  'leave': 24255,
#  'sippy': 37778,
#  'cup': 11672,
#  'today': 42862,
#  'hoping': 20814,
#  'others': 29446,
#  'throw': 42504,
#  'away': 4708,
#  'realize': 33816,
#  'something': 38731,
#  'try': 43715,
#  'myself': 27611,
#  'air': 2995,
#  'disappointed': 13287,
#  'after': 2846,
#  'trying': 43720,
#  'assemble': 4290,
#  'finally': 16929,
#  'please': 31440,
#  'carefully': 8187,
#  'original': 29367,
#  'packaging': 29968,
#  '22': 773,
#  'holding': 20683,
#  'washing': 46105,
#  'dishwasher': 13476,
#  'top': 43042,
#  'rack': 33500,
#  'no': 28256,
#  'major': 25459,
#  'fading': 16402,
#  'scratching': 36449,
#  'images': 21393,
#  'spoons': 39257,
#  'handy': 19870,
#  'real': 33800,
#  'spoon': 39250,
#  'finds': 16941,
#  'handles': 19823,
#  'opts': 29254,
#  'fingers': 16962,
#  'instead': 22247,
#  'unless': 44548,
#  'applesauce': 3890,
#  'noted': 28430,
#  'children': 8888,
#  'learn': 24232,
#  'knob': 23698,
#  'apart': 3808,
#  'seconds': 36676,
#  'joy': 23169,
#  'sorrow': 38837,
#  'barely': 5338,
#  'touched': 43153,
#  'scotch': 36405,
#  'secure': 36696,
#  'where': 46531,
#  'snap': 38377,
#  'hands': 19846,
#  'aren': 4032,
#  'chasing': 8691,
#  'pantry': 30159,
#  'wonderful': 47048,
#  'job': 23092,
#  'point': 31618,
#  'attachment': 4461,
#  'shaped': 37106,
#  'mean': 26056,
#  'doesnt': 13846,
#  'round': 35722,
#  'hope': 20800,
#  'helps': 20335,
#  'gate': 18458,
#  'standard': 39646,
#  'doorway': 13958,
#  'renting': 34687,
#  'town': 43204,
#  'stairs': 39618,
#  'pressure': 32325,
#  'mounted': 27283,
#  'capabilities': 8098,
#  'isn': 22702,
#  'walking': 45929,
#  'curious': 11721,
#  'active': 2481,
#  'crawler': 11284,
#  'person': 30815,
#  'question': 33382,
#  'remains': 34595,
#  'couple': 11070,
#  'sessions': 36974,
#  'guess': 19546,
#  'writing': 47337,
#  'soon': 38778,
#  'organic': 29325,
#  'usa': 45026,
#  'clothes': 9447,
#  'satisfied': 36159,
#  'second': 36671,
#  'travel': 43431,
#  'bib': 6019,
#  'st': 39552,
#  'pictures': 31037,
#  'before': 5782,
#  'eats': 14711,
#  'cake': 7872,
#  'detsroyed': 12870,
#  'research': 34885,
#  'decided': 12218,
#  'magic': 25400,
#  'bumper': 7550,
#  'bed': 5710,
#  'chose': 9018,
#  'important': 21520,
#  'function': 18167,
#  'falling': 16448,
#  'any': 3752,
#  'incidence': 21645,
#  'stays': 39772,
#  'mattress': 25936,
#  'nicely': 28109,
#  'slip': 38120,
#  'secondly': 36675,
#  'climb': 9366,
#  'gets': 18652,
#  'enjoys': 15290,
#  'freedom': 17867,
#  'himself': 20542,
#  'assistance': 4334,
#  'independent': 21793,
#  '32': 1088,
#  'month': 27082,
#  'age': 2879,
#  'rail': 33555,
#  'concept': 10235,
#  'worked': 47147,
#  'thirdly': 42350,
#  'compared': 10019,
#  'fourthly': 17768,
#  'fifthly': 16864,
#  'vacation': 45185,
#  'beach': 5591,
#  'villa': 45601,
#  'south': 38884,
#  'carolina': 8219,
#  'late': 24041,
#  'august': 4556,
#  'may': 25980,
#  'pack': 29956,
#  'there': 42171,
#  'lastly': 24030,
#  'least': 24248,
#  'cheaper': 8715,
#  'summary': 40731,
#  'chicco': 8852,
#  'system': 41287,
#  'including': 21676,
#  'born': 6750,
#  '5lbs': 1607,
#  '14oz': 402,
#  'snug': 38489,
#  'day': 12077,
#  'three': 42460,
#  'head': 20119,
#  'shift': 37247,
#  'latch': 24034,
#  'securely': 36702,
#  'produce': 32602,
#  'anybody': 3754,
#  'newborn': 28032,
#  'side': 37517,
#  'able': 2148,
#  'wear': 46253,
#  'cotton': 10988,
#  'flame': 17132,
#  'retardant': 35136,
#  'chemicals': 8792,
#  'understand': 44293,
#  'reviewers': 35267,
#  'change': 8612,
#  'diapers': 12975,
#  'different': 13067,
#  'rooms': 35657,
#  'genie': 18571,
#  'nursery': 28596,
#  'taken': 41403,
#  'trash': 43413,
#  'daily': 11900,
#  'simply': 37700,
#  'taking': 41409,
#  'regularly': 34426,
#  'beginning': 5802,
#  'save': 36187,
#  'expense': 16089,
#  'buying': 7779,
#  'bedroom': 5730,
#  'worry': 47194,
#  'smell': 38275,
#  'exclusively': 15941,
#  'breastfeeding': 7095,
#  'difference': 13063,
#  'become': 5701,
#  'who': 46649,
#  'formula': 17699,
#  'fed': 16688,
#  'poopy': 31771,
#  'house': 20932,
#  'honestly': 20749,
#  'imagine': 21399,
#  'smelling': 38281,
#  'regular': 34425,
#  'trashcan': 43417,
#  'totally': 43125,
#  'eliminated': 14998,
#  'wouldn': 47234,
#  'necessity': 27860,
#  'afford': 2816,
#  'cloths': 9458,
#  'inexpensive': 21880,
#  'absorbent': 2222,
#  'combination': 9808,
#  'guy': 19647,
#  'online': 29072,
#  'knowing': 23719,
#  'wings': 46831,
#  'flap': 17147,
#  'seeing': 36726,
#  'nephews': 27955,
#  'hit': 20609,
#  'wooden': 47080,
#  'construction': 10537,
#  'durable': 14483,
#  'overall': 29659,
#  'purchase': 33124,
#  'breastfed': 7090,
#  'knew': 23679,
#  'bottles': 6810,
#  'risks': 35491,
#  'gas': 18430,
#  'toxic': 43210,
#  'plastic': 31327,
#  'until': 44817,
#  'dr': 14103,
#  'brown': 7292,
#  'eliminate': 14997,
#  'problems': 32541,
#  'average': 4659,
#  'bottle': 6797,
#  'science': 36360,
#  'behind': 5819,
#  'brush': 7322,
#  'teeth': 41679,
#  'opens': 29172,
#  'mouth': 27293,
#  'sees': 36754,
#  'bristles': 7219,
#  'feel': 16715,
#  'gums': 19594,
#  'nubs': 28533,
#  'offer': 28862,
#  'massaging': 25834,
#  'relief': 34553,
#  'fussing': 18266,
#  'recommended': 34101,
#  'reception': 33977,
#  'spotty': 39289,
#  'fantastic': 16498,
#  'clarity': 9204,
#  'pitch': 31210,
#  'amazing': 3371,
#  'camera': 7968,
#  'manuverable': 25686,
#  'anywhere': 3786,
#  'whole': 46659,
#  'unit': 44508,
#  'moved': 27306,
#  'trouble': 43648,
#  'unreliable': 44690,
#  'horrendous': 20844,
#  'most': 27208,
#  'somewhere': 38744,
#  'between': 5983,
#  'rush': 35866,
#  'each': 14584,
#  'happening': 19914,
#  'disturbing': 13734,
#  'everyone': 15778,
#  'craddle': 11192,
#  'haven': 20070,
#  'seen': 36744,
#  'action': 2471,
#  'encourage': 15188,
#  'whatever': 46482,
#  'center': 8483,
#  'hint': 20571,
#  'einstein': 14894,
#  'videos': 45575,
#  'content': 10603,
#  'those': 42409,
#  '10': 48,
#  'minutes': 26630,
#  'alone': 3255,
#  'door': 13939,
#  'jam': 22914,
#  'jumpers': 23244,
#  'damage': 11915,
#  'jams': 22930,
#  'logical': 24875,
#  'short': 37355,
#  'doorjam': 13945,
#  'jumper': 23235,
#  'why': 46686,
#  'spring': 39320,
#  'several': 37012,
#  'metal': 26326,
#  'dritz': 14250,
#  'limited': 24601,
#  'success': 40601,
#  'super': 40798,
#  'apply': 3905,
#  'none': 28316,
#  'loose': 25000,
#  'owl': 29861,
#  'flannel': 17145,
#  'plain': 31289,
#  'gift': 18703,
#  'registry': 34400,
#  'eco': 14742,
#  'friendly': 17965,
#  'alot': 3264,
#  'picked': 31005,
#  'option': 29242,
#  'rolling': 35611,
#  'floor': 17337,
#  'lucky': 25187,
#  'neighbor': 27930,
#  'twins': 43925,
#  'won': 47040,
#  'anymore': 3760,
#  'reading': 33780,
#  'various': 45290,
#  'let': 24379,
#  'tell': 41721,
#  'ladies': 23875,
#  'wants': 45997,
#  'check': 8739,
#  'older': 28969,
#  'brothers': 7288,
#  'sister': 37805,
#  'thinks': 42336,
#  'shopping': 37346,
#  'tiny': 42753,
#  'ride': 35387,
#  'cleaner': 9266,
#  'useful': 45065,
#  'sponge': 39233,
#  'tipped': 42769,
#  'cleaning': 9275,
#  'power': 32037,
#  'thin': 42309,
#  'end': 15200,
#  'friction': 17948,
#  'nipples': 28218,
#  'anti': 3715,
#  'colic': 9652,
#  'valve': 45242,
#  'screw': 36482,
#  'nipple': 28213,
#  'might': 26452,
#  'replace': 34755,
#  'valves': 45246,
#  'unscrew': 44719,
#  'separately': 36886,
#  'pain': 30054,
#  'convenient': 10711,
#  'agree': 2934,
#  'slow': 38187,
#  'flow': 17373,
#  'fast': 16555,
#  'mentioned': 26253,
#  'weeks': 46328,
#  'opinion': 29190,
#  'introduce': 22520,
#  'establish': 15627,
#  'lazy': 24146,
#  'prefer': 32168,
#  'opposed': 29218,
#  'breast': 7085,
#  'harder': 19950,
#  'milk': 26491,
#  'stretch': 40261,
#  'mimic': 26530,
#  'probably': 32518,
#  'next': 28070,
#  'stage': 39592,
#  'favor': 16602,
#  ...}

# %%
all_count = countvectorizer.transform(all_review)
print(all_count.shape)
# Out:
# (86000, 47803)

# %%
bayes_classification = MultinomialNB()

all_labels = [1]*43000 + [0]*43000

bayes_classification.fit(all_count,all_labels )
# Out:
# MultinomialNB()

# %%
review_case5 = "it was not bad. it's so normal"

print(bayes_classification.predict(countvectorizer.transform([review_case5])))
print(bayes_classification.predict_proba(countvectorizer.transform([review_case5])))
# Out:
# [0]
# [[0.88504191 0.11495809]]
